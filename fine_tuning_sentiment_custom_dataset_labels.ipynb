# %%
# !pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.25.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.8/dist-packages (2.7.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from datasets) (3.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
# https://www.kaggle.com/crowdflower/twitter-airline-sentiment
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# File ‘AirlineTweets.csv’ already there; not retrieving.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import torch

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("AirlineTweets.csv")

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df = df[['airline_sentiment', 'text']].copy()

# %%
df.head()
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
df.airline_sentiment.hist()

# %%
target_map = {'positive': 1, 'negative': 0, 'neutral': 2}
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df2 = df[['text', 'target']]
df2.columns = ['sentence', 'label']
df2.to_csv('data.csv', index=None)

# %%
# !head data.csv
# Out:
# sentence,label
# @VirginAmerica What @dhepburn said.,2
# @VirginAmerica plus you've added commercials to the experience... tacky.,1
# @VirginAmerica I didn't today... Must mean I need to take another trip!,2
# "@VirginAmerica it's really aggressive to blast obnoxious ""entertainment"" in your guests' faces &amp; they have little recourse",0
# @VirginAmerica and it's a really big bad thing about it,0
# "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.
# it's really the only bad thing about flying VA",0
# "@VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)",1
# "@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP",2

# %%
from datasets import load_dataset
raw_dataset = load_dataset('csv', data_files='data.csv')
# Out:
# WARNING:datasets.builder:Using custom data configuration default-1a330a011f63eae8
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-1a330a011f63eae8/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-1a330a011f63eae8/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 14640
#     })
# })

# %%
split = raw_dataset['train'].train_test_split(test_size=.3, seed=42)

# %%
split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 10248
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 4392
#     })
# })

# %%
# if there are multinle csv files
# load_dataset('csv',  data_files=['file1.csv', 'file2.csv'])

# %%
# if there is already train test split
# load_dataset('csv',  data_files={
#                                   'train': ['file1.csv', 'file2.csv'],
#                                   'test': 'test.csv'
#                                  })

# %%
checkpoint = 'distilbert-base-cased'

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/411 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
def tokenize_fn(batch):
    return tokenizer(batch['sentence'], truncation=True)

# %%
tokenized_datasets = split.map(tokenize_fn, batched=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?ba/s]
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %%
from transformers import AutoModelForSequenceClassification, \
    AutoConfig, Trainer, TrainingArguments

# %%
config = AutoConfig.from_pretrained(checkpoint)

# %%
config
# Out:
# DistilBertConfig {
#   "_name_or_path": "distilbert-base-cased",
#   "activation": "gelu",
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.25.1",
#   "vocab_size": 28996
# }

# %%
config.id2label
# Out:
# {0: 'LABEL_0', 1: 'LABEL_1'}

# %%
config.label2id
# Out:
# {'LABEL_0': 0, 'LABEL_1': 1}

# %%
config.id2label = {v:k for k,v in target_map.items()}
config.label2id = target_map

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    checkpoint, config=config)
# Out:
# Downloading:   0%|          | 0.00/263M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.1-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.1

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DistilBertForSequenceClassification                     --
# ├─DistilBertModel: 1-1                                  --
# │    └─Embeddings: 2-1                                  --
# │    │    └─Embedding: 3-1                              22,268,928
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─LayerNorm: 3-3                              1,536
# │    │    └─Dropout: 3-4                                --
# │    └─Transformer: 2-2                                 --
# │    │    └─ModuleList: 3-5                             42,527,232
# ├─Linear: 1-2                                           590,592
# ├─Linear: 1-3                                           2,307
# ├─Dropout: 1-4                                          --
# ================================================================================
# Total params: 65,783,811
# Trainable params: 65,783,811
# Non-trainable params: 0
# ================================================================================

# %%
training_args = TrainingArguments(
    output_dir='training_dir',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64
)

# %%
def compute_metrics(logits_and_labels):
    logits, labels = logits_and_labels
    predictions = np.argmax(logits, axis=-1)
    acc = np.mean(predictions==labels)
    f1 = f1_score(labels, predictions, average='macro') 
    return {'accuracy': acc, 'f1': f1}

# %%
trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 10248
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1923
#   Number of trainable parameters = 65783811
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1923' max='1923' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1923/1923 03:06, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.555100</td>
#       <td>0.428614</td>
#       <td>0.829690</td>
#       <td>0.777246</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.343900</td>
#       <td>0.506039</td>
#       <td>0.830146</td>
#       <td>0.780092</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.238900</td>
#       <td>0.656210</td>
#       <td>0.832650</td>
#       <td>0.780825</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-641
# Configuration saved in training_dir/checkpoint-641/config.json
# Model weights saved in training_dir/checkpoint-641/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-641/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-641/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-1282
# Configuration saved in training_dir/checkpoint-1282/config.json
# Model weights saved in training_dir/checkpoint-1282/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-1282/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-1282/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-1923
# Configuration saved in training_dir/checkpoint-1923/config.json
# Model weights saved in training_dir/checkpoint-1923/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-1923/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-1923/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1923, training_loss=0.32957679879460805, metrics={'train_runtime': 188.8463, 'train_samples_per_second': 162.799, 'train_steps_per_second': 10.183, 'total_flos': 388376501242176.0, 'train_loss': 0.32957679879460805, 'epoch': 3.0})

# %%
# !ls training_dir
# Out:
# checkpoint-1282  checkpoint-1923  checkpoint-641  runs

# %%
from transformers import pipeline

# %%
savedmodel = pipeline('text-classification',
                      model='training_dir/checkpoint-1282',
                      device=0)
# Out:
# loading configuration file training_dir/checkpoint-1282/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "training_dir/checkpoint-1282",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "negative",
#     "1": "positive",
#     "2": "neutral"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "negative": 0,
#     "neutral": 2,
#     "positive": 1
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "vocab_size": 28996
# }
#
# loading configuration file training_dir/checkpoint-1282/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "training_dir/checkpoint-1282",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "negative",
#     "1": "positive",
#     "2": "neutral"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "negative": 0,
#     "neutral": 2,
#     "positive": 1
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "vocab_size": 28996
# }
#
# loading weights file training_dir/checkpoint-1282/pytorch_model.bin
# All model checkpoint weights were used when initializing DistilBertForSequenceClassification.
#
# All the weights of DistilBertForSequenceClassification were initialized from the model checkpoint at training_dir/checkpoint-1282.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForSequenceClassification for predictions without further training.
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json

# %%
split['test']
# Out:
# Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 4392
# })

# %%
test_pred = savedmodel(split['test']['sentence'])
# Out:
# Disabling tokenizer parallelism, we're using DataLoader multithreading already

# %%
test_pred
# Out:
# [{'label': 'positive', 'score': 0.9336013793945312},
#  {'label': 'positive', 'score': 0.9537263512611389},
#  {'label': 'positive', 'score': 0.7498485445976257},
#  {'label': 'positive', 'score': 0.827085554599762},
#  {'label': 'neutral', 'score': 0.9154884815216064},
#  {'label': 'negative', 'score': 0.9954437017440796},
#  {'label': 'neutral', 'score': 0.9177980422973633},
#  {'label': 'neutral', 'score': 0.9833530187606812},
#  {'label': 'neutral', 'score': 0.5499528050422668},
#  {'label': 'negative', 'score': 0.9957461953163147},
#  {'label': 'negative', 'score': 0.9824783205986023},
#  {'label': 'negative', 'score': 0.9939814209938049},
#  {'label': 'positive', 'score': 0.931094229221344},
#  {'label': 'negative', 'score': 0.9790027737617493},
#  {'label': 'neutral', 'score': 0.9882832765579224},
#  {'label': 'positive', 'score': 0.6564459800720215},
#  {'label': 'negative', 'score': 0.6286470890045166},
#  {'label': 'negative', 'score': 0.9961387515068054},
#  {'label': 'negative', 'score': 0.9328294992446899},
#  {'label': 'negative', 'score': 0.9938072562217712},
#  {'label': 'neutral', 'score': 0.7101944088935852},
#  {'label': 'neutral', 'score': 0.6644816398620605},
#  {'label': 'negative', 'score': 0.7176446318626404},
#  {'label': 'negative', 'score': 0.6589627265930176},
#  {'label': 'negative', 'score': 0.9962526559829712},
#  {'label': 'negative', 'score': 0.6013213992118835},
#  {'label': 'negative', 'score': 0.9961917400360107},
#  {'label': 'negative', 'score': 0.996117353439331},
#  {'label': 'negative', 'score': 0.9960516095161438},
#  {'label': 'negative', 'score': 0.9952384233474731},
#  {'label': 'negative', 'score': 0.9962687492370605},
#  {'label': 'negative', 'score': 0.8350987434387207},
#  {'label': 'negative', 'score': 0.9961273074150085},
#  {'label': 'negative', 'score': 0.9963979721069336},
#  {'label': 'positive', 'score': 0.9366649389266968},
#  {'label': 'negative', 'score': 0.9955734014511108},
#  {'label': 'positive', 'score': 0.6759090423583984},
#  {'label': 'negative', 'score': 0.9754880666732788},
#  {'label': 'negative', 'score': 0.9888353943824768},
#  {'label': 'neutral', 'score': 0.8691381216049194},
#  {'label': 'negative', 'score': 0.9957017302513123},
#  {'label': 'negative', 'score': 0.9847724437713623},
#  {'label': 'negative', 'score': 0.9946295022964478},
#  {'label': 'negative', 'score': 0.6345236897468567},
#  {'label': 'positive', 'score': 0.6714626550674438},
#  {'label': 'neutral', 'score': 0.6028451919555664},
#  {'label': 'negative', 'score': 0.9831767082214355},
#  {'label': 'positive', 'score': 0.9006432890892029},
#  {'label': 'negative', 'score': 0.9960527420043945},
#  {'label': 'negative', 'score': 0.9965240359306335},
#  {'label': 'negative', 'score': 0.9743743538856506},
#  {'label': 'negative', 'score': 0.9240906834602356},
#  {'label': 'negative', 'score': 0.9241757392883301},
#  {'label': 'negative', 'score': 0.9961130619049072},
#  {'label': 'negative', 'score': 0.9940540194511414},
#  {'label': 'negative', 'score': 0.9962831139564514},
#  {'label': 'negative', 'score': 0.8081426620483398},
#  {'label': 'neutral', 'score': 0.9855288863182068},
#  {'label': 'negative', 'score': 0.9936337471008301},
#  {'label': 'positive', 'score': 0.8762075901031494},
#  {'label': 'negative', 'score': 0.9937735795974731},
#  {'label': 'negative', 'score': 0.9933739900588989},
#  {'label': 'negative', 'score': 0.9953006505966187},
#  {'label': 'negative', 'score': 0.9949200749397278},
#  {'label': 'negative', 'score': 0.9241567850112915},
#  {'label': 'neutral', 'score': 0.9879266619682312},
#  {'label': 'negative', 'score': 0.9932952523231506},
#  {'label': 'negative', 'score': 0.9966807961463928},
#  {'label': 'negative', 'score': 0.9960184693336487},
#  {'label': 'negative', 'score': 0.8783666491508484},
#  {'label': 'negative', 'score': 0.9884775280952454},
#  {'label': 'negative', 'score': 0.9015534520149231},
#  {'label': 'negative', 'score': 0.9014169573783875},
#  {'label': 'negative', 'score': 0.9387550354003906},
#  {'label': 'neutral', 'score': 0.796937882900238},
#  {'label': 'negative', 'score': 0.8943488001823425},
#  {'label': 'negative', 'score': 0.9958009123802185},
#  {'label': 'negative', 'score': 0.9760323762893677},
#  {'label': 'negative', 'score': 0.9951366782188416},
#  {'label': 'negative', 'score': 0.944403886795044},
#  {'label': 'negative', 'score': 0.9968327879905701},
#  {'label': 'negative', 'score': 0.7305206656455994},
#  {'label': 'positive', 'score': 0.9427579045295715},
#  {'label': 'negative', 'score': 0.9653170704841614},
#  {'label': 'positive', 'score': 0.9346343874931335},
#  {'label': 'neutral', 'score': 0.9679362773895264},
#  {'label': 'negative', 'score': 0.9954572916030884},
#  {'label': 'negative', 'score': 0.982319176197052},
#  {'label': 'negative', 'score': 0.9913647174835205},
#  {'label': 'neutral', 'score': 0.7988406419754028},
#  {'label': 'negative', 'score': 0.9652227163314819},
#  {'label': 'negative', 'score': 0.981223464012146},
#  {'label': 'negative', 'score': 0.9917888045310974},
#  {'label': 'negative', 'score': 0.5210760235786438},
#  {'label': 'negative', 'score': 0.9817968606948853},
#  {'label': 'negative', 'score': 0.9922054409980774},
#  {'label': 'negative', 'score': 0.9954882264137268},
#  {'label': 'negative', 'score': 0.9966198205947876},
#  {'label': 'negative', 'score': 0.9796654582023621},
#  {'label': 'negative', 'score': 0.9920614957809448},
#  {'label': 'negative', 'score': 0.9968668818473816},
#  {'label': 'neutral', 'score': 0.9903451800346375},
#  {'label': 'neutral', 'score': 0.9618838429450989},
#  {'label': 'neutral', 'score': 0.9672556519508362},
#  {'label': 'neutral', 'score': 0.7876800894737244},
#  {'label': 'negative', 'score': 0.9963891506195068},
#  {'label': 'negative', 'score': 0.7619127035140991},
#  {'label': 'negative', 'score': 0.9897300004959106},
#  {'label': 'negative', 'score': 0.9895815849304199},
#  {'label': 'negative', 'score': 0.9963021278381348},
#  {'label': 'negative', 'score': 0.9613752961158752},
#  {'label': 'negative', 'score': 0.9965044260025024},
#  {'label': 'negative', 'score': 0.9818010330200195},
#  {'label': 'neutral', 'score': 0.7221656441688538},
#  {'label': 'negative', 'score': 0.9878771305084229},
#  {'label': 'neutral', 'score': 0.9732259511947632},
#  {'label': 'negative', 'score': 0.9952473044395447},
#  {'label': 'neutral', 'score': 0.6877533793449402},
#  {'label': 'negative', 'score': 0.9956907629966736},
#  {'label': 'neutral', 'score': 0.9777657389640808},
#  {'label': 'neutral', 'score': 0.9788610339164734},
#  {'label': 'neutral', 'score': 0.9457733631134033},
#  {'label': 'neutral', 'score': 0.9677937626838684},
#  {'label': 'neutral', 'score': 0.973517894744873},
#  {'label': 'negative', 'score': 0.9829550385475159},
#  {'label': 'negative', 'score': 0.9964048862457275},
#  {'label': 'negative', 'score': 0.9768863320350647},
#  {'label': 'negative', 'score': 0.9963079690933228},
#  {'label': 'neutral', 'score': 0.735423743724823},
#  {'label': 'negative', 'score': 0.9952979683876038},
#  {'label': 'positive', 'score': 0.7439247369766235},
#  {'label': 'negative', 'score': 0.9957616925239563},
#  {'label': 'negative', 'score': 0.9748340845108032},
#  {'label': 'positive', 'score': 0.9761334657669067},
#  {'label': 'neutral', 'score': 0.9851970672607422},
#  {'label': 'negative', 'score': 0.9878596663475037},
#  {'label': 'negative', 'score': 0.9949937462806702},
#  {'label': 'negative', 'score': 0.9780373573303223},
#  {'label': 'negative', 'score': 0.9962357878684998},
#  {'label': 'negative', 'score': 0.9964853525161743},
#  {'label': 'negative', 'score': 0.9901935458183289},
#  {'label': 'negative', 'score': 0.991446852684021},
#  {'label': 'negative', 'score': 0.995462954044342},
#  {'label': 'negative', 'score': 0.9934884309768677},
#  {'label': 'neutral', 'score': 0.9519491195678711},
#  {'label': 'neutral', 'score': 0.9220406413078308},
#  {'label': 'neutral', 'score': 0.8610013723373413},
#  {'label': 'negative', 'score': 0.9963417649269104},
#  {'label': 'negative', 'score': 0.9960313439369202},
#  {'label': 'negative', 'score': 0.9966894388198853},
#  {'label': 'negative', 'score': 0.9962959885597229},
#  {'label': 'neutral', 'score': 0.8711424469947815},
#  {'label': 'neutral', 'score': 0.9871460199356079},
#  {'label': 'neutral', 'score': 0.937073290348053},
#  {'label': 'positive', 'score': 0.9336199760437012},
#  {'label': 'neutral', 'score': 0.8327541947364807},
#  {'label': 'negative', 'score': 0.9873408675193787},
#  {'label': 'negative', 'score': 0.9829683899879456},
#  {'label': 'negative', 'score': 0.9962707757949829},
#  {'label': 'negative', 'score': 0.9962040781974792},
#  {'label': 'neutral', 'score': 0.8536580204963684},
#  {'label': 'negative', 'score': 0.9962639212608337},
#  {'label': 'positive', 'score': 0.7838867902755737},
#  {'label': 'negative', 'score': 0.9960737228393555},
#  {'label': 'negative', 'score': 0.8453406095504761},
#  {'label': 'negative', 'score': 0.8291819095611572},
#  {'label': 'negative', 'score': 0.9953847527503967},
#  {'label': 'negative', 'score': 0.9917868971824646},
#  {'label': 'neutral', 'score': 0.8846146464347839},
#  {'label': 'neutral', 'score': 0.9754765629768372},
#  {'label': 'negative', 'score': 0.9962474703788757},
#  {'label': 'negative', 'score': 0.9691569805145264},
#  {'label': 'negative', 'score': 0.820253849029541},
#  {'label': 'neutral', 'score': 0.9548225402832031},
#  {'label': 'positive', 'score': 0.5002300143241882},
#  {'label': 'positive', 'score': 0.4855576753616333},
#  {'label': 'negative', 'score': 0.8648810982704163},
#  {'label': 'negative', 'score': 0.9964160919189453},
#  {'label': 'negative', 'score': 0.9954428672790527},
#  {'label': 'negative', 'score': 0.9851952791213989},
#  {'label': 'negative', 'score': 0.9878506064414978},
#  {'label': 'negative', 'score': 0.6898236274719238},
#  {'label': 'negative', 'score': 0.9966880679130554},
#  {'label': 'negative', 'score': 0.9958685636520386},
#  {'label': 'negative', 'score': 0.9968994855880737},
#  {'label': 'neutral', 'score': 0.5934948325157166},
#  {'label': 'neutral', 'score': 0.9841929078102112},
#  {'label': 'negative', 'score': 0.995960533618927},
#  {'label': 'positive', 'score': 0.9805319905281067},
#  {'label': 'negative', 'score': 0.8077484369277954},
#  {'label': 'negative', 'score': 0.9014420509338379},
#  {'label': 'negative', 'score': 0.9912827014923096},
#  {'label': 'negative', 'score': 0.9892897009849548},
#  {'label': 'negative', 'score': 0.8876430988311768},
#  {'label': 'negative', 'score': 0.9540237784385681},
#  {'label': 'neutral', 'score': 0.8653913736343384},
#  {'label': 'positive', 'score': 0.9629709124565125},
#  {'label': 'negative', 'score': 0.6513360738754272},
#  {'label': 'negative', 'score': 0.99594646692276},
#  {'label': 'negative', 'score': 0.9286057353019714},
#  {'label': 'neutral', 'score': 0.891460657119751},
#  {'label': 'negative', 'score': 0.8979003429412842},
#  {'label': 'neutral', 'score': 0.9401207566261292},
#  {'label': 'negative', 'score': 0.9970663189888},
#  {'label': 'negative', 'score': 0.9856113195419312},
#  {'label': 'positive', 'score': 0.8816357254981995},
#  {'label': 'neutral', 'score': 0.9881110191345215},
#  {'label': 'negative', 'score': 0.9959529638290405},
#  {'label': 'negative', 'score': 0.9963666200637817},
#  {'label': 'negative', 'score': 0.8699291944503784},
#  {'label': 'neutral', 'score': 0.5219060182571411},
#  {'label': 'neutral', 'score': 0.979322612285614},
#  {'label': 'positive', 'score': 0.9231524467468262},
#  {'label': 'neutral', 'score': 0.6807720065116882},
#  {'label': 'negative', 'score': 0.9922836422920227},
#  {'label': 'neutral', 'score': 0.9908326268196106},
#  {'label': 'neutral', 'score': 0.9905808568000793},
#  {'label': 'negative', 'score': 0.994186282157898},
#  {'label': 'neutral', 'score': 0.9903604984283447},
#  {'label': 'neutral', 'score': 0.9721674919128418},
#  {'label': 'negative', 'score': 0.9419291615486145},
#  {'label': 'negative', 'score': 0.9954981803894043},
#  {'label': 'negative', 'score': 0.9957659244537354},
#  {'label': 'neutral', 'score': 0.967384934425354},
#  {'label': 'positive', 'score': 0.7792054414749146},
#  {'label': 'negative', 'score': 0.8888201117515564},
#  {'label': 'negative', 'score': 0.8630343079566956},
#  {'label': 'negative', 'score': 0.9937765598297119},
#  {'label': 'negative', 'score': 0.9904084205627441},
#  {'label': 'negative', 'score': 0.9771629571914673},
#  {'label': 'neutral', 'score': 0.8866307735443115},
#  {'label': 'negative', 'score': 0.9645729064941406},
#  {'label': 'negative', 'score': 0.9952297210693359},
#  {'label': 'negative', 'score': 0.9966033697128296},
#  {'label': 'negative', 'score': 0.9881569743156433},
#  {'label': 'positive', 'score': 0.9171213507652283},
#  {'label': 'negative', 'score': 0.9580208659172058},
#  {'label': 'negative', 'score': 0.9263829588890076},
#  {'label': 'negative', 'score': 0.9954975843429565},
#  {'label': 'negative', 'score': 0.9865759611129761},
#  {'label': 'negative', 'score': 0.993225634098053},
#  {'label': 'neutral', 'score': 0.7934508323669434},
#  {'label': 'negative', 'score': 0.4917767643928528},
#  {'label': 'positive', 'score': 0.5859758853912354},
#  {'label': 'negative', 'score': 0.9967170357704163},
#  {'label': 'negative', 'score': 0.9542189836502075},
#  {'label': 'negative', 'score': 0.9470483660697937},
#  {'label': 'neutral', 'score': 0.6216826438903809},
#  {'label': 'negative', 'score': 0.9151352047920227},
#  {'label': 'neutral', 'score': 0.9687318801879883},
#  {'label': 'negative', 'score': 0.9944002032279968},
#  {'label': 'negative', 'score': 0.9883673787117004},
#  {'label': 'negative', 'score': 0.9959624409675598},
#  {'label': 'negative', 'score': 0.9960600733757019},
#  {'label': 'negative', 'score': 0.9957298636436462},
#  {'label': 'negative', 'score': 0.8350436687469482},
#  {'label': 'negative', 'score': 0.9206469058990479},
#  {'label': 'negative', 'score': 0.9967195391654968},
#  {'label': 'negative', 'score': 0.9809351563453674},
#  {'label': 'neutral', 'score': 0.737223744392395},
#  {'label': 'positive', 'score': 0.9699150323867798},
#  {'label': 'negative', 'score': 0.9945039749145508},
#  {'label': 'negative', 'score': 0.9953416585922241},
#  {'label': 'positive', 'score': 0.9835129380226135},
#  {'label': 'positive', 'score': 0.5045945048332214},
#  {'label': 'negative', 'score': 0.8682501912117004},
#  {'label': 'negative', 'score': 0.996004045009613},
#  {'label': 'negative', 'score': 0.9327376484870911},
#  {'label': 'negative', 'score': 0.7974459528923035},
#  {'label': 'positive', 'score': 0.9744018316268921},
#  {'label': 'negative', 'score': 0.9962971806526184},
#  {'label': 'negative', 'score': 0.8330373764038086},
#  {'label': 'neutral', 'score': 0.6761892437934875},
#  {'label': 'negative', 'score': 0.857513964176178},
#  {'label': 'negative', 'score': 0.8514031767845154},
#  {'label': 'positive', 'score': 0.9120824337005615},
#  {'label': 'negative', 'score': 0.9965607523918152},
#  {'label': 'neutral', 'score': 0.9520148038864136},
#  {'label': 'neutral', 'score': 0.9852076768875122},
#  {'label': 'negative', 'score': 0.9309285283088684},
#  {'label': 'negative', 'score': 0.9960907101631165},
#  {'label': 'negative', 'score': 0.9912945628166199},
#  {'label': 'neutral', 'score': 0.9407256841659546},
#  {'label': 'negative', 'score': 0.9959056377410889},
#  {'label': 'positive', 'score': 0.962574303150177},
#  {'label': 'neutral', 'score': 0.799822986125946},
#  {'label': 'negative', 'score': 0.9911466240882874},
#  {'label': 'negative', 'score': 0.9961452484130859},
#  {'label': 'negative', 'score': 0.9945468902587891},
#  {'label': 'negative', 'score': 0.9963852167129517},
#  {'label': 'negative', 'score': 0.9649197459220886},
#  {'label': 'negative', 'score': 0.9965885877609253},
#  {'label': 'neutral', 'score': 0.9662056565284729},
#  {'label': 'neutral', 'score': 0.8723410964012146},
#  {'label': 'negative', 'score': 0.9667812585830688},
#  {'label': 'negative', 'score': 0.9791842699050903},
#  {'label': 'neutral', 'score': 0.7920488119125366},
#  {'label': 'neutral', 'score': 0.9897210001945496},
#  {'label': 'negative', 'score': 0.9964068531990051},
#  {'label': 'negative', 'score': 0.9615964889526367},
#  {'label': 'negative', 'score': 0.9950874447822571},
#  {'label': 'neutral', 'score': 0.9777598977088928},
#  {'label': 'neutral', 'score': 0.9211322665214539},
#  {'label': 'negative', 'score': 0.9952030181884766},
#  {'label': 'neutral', 'score': 0.7982600331306458},
#  {'label': 'negative', 'score': 0.97536700963974},
#  {'label': 'positive', 'score': 0.9555437564849854},
#  {'label': 'neutral', 'score': 0.9814105033874512},
#  {'label': 'negative', 'score': 0.6275354027748108},
#  {'label': 'negative', 'score': 0.993432879447937},
#  {'label': 'negative', 'score': 0.9825992584228516},
#  {'label': 'negative', 'score': 0.994820237159729},
#  {'label': 'negative', 'score': 0.9969315528869629},
#  {'label': 'neutral', 'score': 0.8723236322402954},
#  {'label': 'negative', 'score': 0.9887535572052002},
#  {'label': 'positive', 'score': 0.9115391969680786},
#  {'label': 'neutral', 'score': 0.6845943927764893},
#  {'label': 'negative', 'score': 0.9631408452987671},
#  {'label': 'negative', 'score': 0.987929105758667},
#  {'label': 'negative', 'score': 0.9944041967391968},
#  {'label': 'negative', 'score': 0.9922095537185669},
#  {'label': 'negative', 'score': 0.7313798666000366},
#  {'label': 'neutral', 'score': 0.7657222747802734},
#  {'label': 'negative', 'score': 0.6541679501533508},
#  {'label': 'negative', 'score': 0.9854335784912109},
#  {'label': 'negative', 'score': 0.8851010203361511},
#  {'label': 'positive', 'score': 0.8836400508880615},
#  {'label': 'negative', 'score': 0.9858894348144531},
#  {'label': 'negative', 'score': 0.6763325929641724},
#  {'label': 'negative', 'score': 0.9756253361701965},
#  {'label': 'neutral', 'score': 0.989022970199585},
#  {'label': 'negative', 'score': 0.9958635568618774},
#  {'label': 'negative', 'score': 0.9949127435684204},
#  {'label': 'positive', 'score': 0.7302335500717163},
#  {'label': 'negative', 'score': 0.9946905970573425},
#  {'label': 'negative', 'score': 0.9951406717300415},
#  {'label': 'neutral', 'score': 0.6924857497215271},
#  {'label': 'negative', 'score': 0.991701066493988},
#  {'label': 'neutral', 'score': 0.8004348278045654},
#  {'label': 'positive', 'score': 0.8657788038253784},
#  {'label': 'negative', 'score': 0.8489166498184204},
#  {'label': 'negative', 'score': 0.9953611493110657},
#  {'label': 'negative', 'score': 0.9954262375831604},
#  {'label': 'negative', 'score': 0.9840748310089111},
#  {'label': 'negative', 'score': 0.9624899625778198},
#  {'label': 'neutral', 'score': 0.7045801281929016},
#  {'label': 'negative', 'score': 0.9218183755874634},
#  {'label': 'negative', 'score': 0.9438087344169617},
#  {'label': 'negative', 'score': 0.9916360378265381},
#  {'label': 'positive', 'score': 0.9334373474121094},
#  {'label': 'neutral', 'score': 0.9747398495674133},
#  {'label': 'positive', 'score': 0.9363880753517151},
#  {'label': 'positive', 'score': 0.9391533732414246},
#  {'label': 'negative', 'score': 0.996819019317627},
#  {'label': 'neutral', 'score': 0.9898245930671692},
#  {'label': 'neutral', 'score': 0.9000652432441711},
#  {'label': 'negative', 'score': 0.8270067572593689},
#  {'label': 'positive', 'score': 0.8706080317497253},
#  {'label': 'neutral', 'score': 0.9161504507064819},
#  {'label': 'negative', 'score': 0.9954224228858948},
#  {'label': 'negative', 'score': 0.9053006172180176},
#  {'label': 'negative', 'score': 0.9922794103622437},
#  {'label': 'negative', 'score': 0.9910091161727905},
#  {'label': 'negative', 'score': 0.9344388246536255},
#  {'label': 'neutral', 'score': 0.9689635634422302},
#  {'label': 'negative', 'score': 0.996473491191864},
#  {'label': 'negative', 'score': 0.9970633387565613},
#  {'label': 'positive', 'score': 0.9520634412765503},
#  {'label': 'negative', 'score': 0.9855493903160095},
#  {'label': 'negative', 'score': 0.9532948732376099},
#  {'label': 'neutral', 'score': 0.9851524829864502},
#  {'label': 'negative', 'score': 0.995677649974823},
#  {'label': 'positive', 'score': 0.9684975743293762},
#  {'label': 'negative', 'score': 0.9957184195518494},
#  {'label': 'positive', 'score': 0.9147404432296753},
#  {'label': 'negative', 'score': 0.9956028461456299},
#  {'label': 'neutral', 'score': 0.9667245149612427},
#  {'label': 'negative', 'score': 0.9267488121986389},
#  {'label': 'positive', 'score': 0.9610045552253723},
#  {'label': 'neutral', 'score': 0.9824777245521545},
#  {'label': 'negative', 'score': 0.9963060617446899},
#  {'label': 'negative', 'score': 0.9912856221199036},
#  {'label': 'negative', 'score': 0.7641246914863586},
#  {'label': 'negative', 'score': 0.9915652275085449},
#  {'label': 'positive', 'score': 0.9791293144226074},
#  {'label': 'negative', 'score': 0.9091386795043945},
#  {'label': 'negative', 'score': 0.9963864088058472},
#  {'label': 'positive', 'score': 0.7821782231330872},
#  {'label': 'positive', 'score': 0.9525355100631714},
#  {'label': 'negative', 'score': 0.8582666516304016},
#  {'label': 'negative', 'score': 0.995875895023346},
#  {'label': 'negative', 'score': 0.9961258769035339},
#  {'label': 'negative', 'score': 0.9682555794715881},
#  {'label': 'negative', 'score': 0.9691212773323059},
#  {'label': 'positive', 'score': 0.9418883919715881},
#  {'label': 'negative', 'score': 0.9700435996055603},
#  {'label': 'negative', 'score': 0.9926510453224182},
#  {'label': 'positive', 'score': 0.8597596883773804},
#  {'label': 'negative', 'score': 0.9960183501243591},
#  {'label': 'negative', 'score': 0.5064618587493896},
#  {'label': 'neutral', 'score': 0.7140206098556519},
#  {'label': 'positive', 'score': 0.5513771772384644},
#  {'label': 'negative', 'score': 0.9847346544265747},
#  {'label': 'negative', 'score': 0.9614550471305847},
#  {'label': 'negative', 'score': 0.9949185252189636},
#  {'label': 'negative', 'score': 0.9966417551040649},
#  {'label': 'positive', 'score': 0.9179956912994385},
#  {'label': 'negative', 'score': 0.9766905903816223},
#  {'label': 'neutral', 'score': 0.9818567633628845},
#  {'label': 'negative', 'score': 0.9964269995689392},
#  {'label': 'negative', 'score': 0.9890074729919434},
#  {'label': 'neutral', 'score': 0.8552173376083374},
#  {'label': 'negative', 'score': 0.9907498955726624},
#  {'label': 'negative', 'score': 0.9832707047462463},
#  {'label': 'negative', 'score': 0.9456227421760559},
#  {'label': 'negative', 'score': 0.8811030983924866},
#  {'label': 'neutral', 'score': 0.9702704548835754},
#  {'label': 'neutral', 'score': 0.9742993116378784},
#  {'label': 'neutral', 'score': 0.9810693264007568},
#  {'label': 'negative', 'score': 0.9909183979034424},
#  {'label': 'neutral', 'score': 0.987356424331665},
#  {'label': 'neutral', 'score': 0.9714113473892212},
#  {'label': 'negative', 'score': 0.970212996006012},
#  {'label': 'positive', 'score': 0.9531753063201904},
#  {'label': 'negative', 'score': 0.9860677123069763},
#  {'label': 'negative', 'score': 0.9598389863967896},
#  {'label': 'negative', 'score': 0.6667665839195251},
#  {'label': 'negative', 'score': 0.9176308512687683},
#  {'label': 'negative', 'score': 0.9957745671272278},
#  {'label': 'negative', 'score': 0.9390084743499756},
#  {'label': 'neutral', 'score': 0.930162250995636},
#  {'label': 'negative', 'score': 0.9579885005950928},
#  {'label': 'positive', 'score': 0.8930158615112305},
#  {'label': 'negative', 'score': 0.5077747106552124},
#  {'label': 'neutral', 'score': 0.8514546751976013},
#  {'label': 'negative', 'score': 0.8824638724327087},
#  {'label': 'negative', 'score': 0.9535805583000183},
#  {'label': 'negative', 'score': 0.9953941106796265},
#  {'label': 'negative', 'score': 0.8790910840034485},
#  {'label': 'negative', 'score': 0.9948699474334717},
#  {'label': 'negative', 'score': 0.9965655207633972},
#  {'label': 'positive', 'score': 0.9137393832206726},
#  {'label': 'negative', 'score': 0.9923455119132996},
#  {'label': 'negative', 'score': 0.9928255081176758},
#  {'label': 'negative', 'score': 0.9965595602989197},
#  {'label': 'neutral', 'score': 0.8030708432197571},
#  {'label': 'negative', 'score': 0.993013322353363},
#  {'label': 'negative', 'score': 0.9964879751205444},
#  {'label': 'neutral', 'score': 0.8732168078422546},
#  {'label': 'negative', 'score': 0.9956656098365784},
#  {'label': 'negative', 'score': 0.9960230588912964},
#  {'label': 'neutral', 'score': 0.6687775254249573},
#  {'label': 'neutral', 'score': 0.9827977418899536},
#  {'label': 'negative', 'score': 0.989854633808136},
#  {'label': 'negative', 'score': 0.9898056983947754},
#  {'label': 'neutral', 'score': 0.8782731294631958},
#  {'label': 'negative', 'score': 0.9948843121528625},
#  {'label': 'positive', 'score': 0.9610691070556641},
#  {'label': 'negative', 'score': 0.5579313039779663},
#  {'label': 'neutral', 'score': 0.5455021262168884},
#  {'label': 'negative', 'score': 0.9953159093856812},
#  {'label': 'negative', 'score': 0.9913787841796875},
#  {'label': 'negative', 'score': 0.931317925453186},
#  {'label': 'negative', 'score': 0.9964401125907898},
#  {'label': 'neutral', 'score': 0.6414446830749512},
#  {'label': 'neutral', 'score': 0.9760765433311462},
#  {'label': 'positive', 'score': 0.9564720392227173},
#  {'label': 'negative', 'score': 0.996444046497345},
#  {'label': 'positive', 'score': 0.9722259044647217},
#  {'label': 'negative', 'score': 0.7300032377243042},
#  {'label': 'neutral', 'score': 0.9875754117965698},
#  {'label': 'negative', 'score': 0.6166674494743347},
#  {'label': 'negative', 'score': 0.9964780211448669},
#  {'label': 'negative', 'score': 0.8953099250793457},
#  {'label': 'neutral', 'score': 0.9817173480987549},
#  {'label': 'negative', 'score': 0.9902744293212891},
#  {'label': 'negative', 'score': 0.6609148383140564},
#  {'label': 'negative', 'score': 0.9825665354728699},
#  {'label': 'positive', 'score': 0.9622942805290222},
#  {'label': 'neutral', 'score': 0.9775093793869019},
#  {'label': 'neutral', 'score': 0.858572244644165},
#  {'label': 'negative', 'score': 0.993707537651062},
#  {'label': 'negative', 'score': 0.9934661984443665},
#  {'label': 'negative', 'score': 0.8665159940719604},
#  {'label': 'negative', 'score': 0.9953235983848572},
#  {'label': 'neutral', 'score': 0.964316189289093},
#  {'label': 'neutral', 'score': 0.7261173725128174},
#  {'label': 'neutral', 'score': 0.9872293472290039},
#  {'label': 'negative', 'score': 0.992039680480957},
#  {'label': 'negative', 'score': 0.9961321353912354},
#  {'label': 'negative', 'score': 0.98799729347229},
#  {'label': 'negative', 'score': 0.5711507201194763},
#  {'label': 'neutral', 'score': 0.9806340932846069},
#  {'label': 'negative', 'score': 0.9953805208206177},
#  {'label': 'negative', 'score': 0.9854536056518555},
#  {'label': 'neutral', 'score': 0.9045872092247009},
#  {'label': 'neutral', 'score': 0.9843438863754272},
#  {'label': 'negative', 'score': 0.9941334128379822},
#  {'label': 'negative', 'score': 0.977368950843811},
#  {'label': 'positive', 'score': 0.7449413537979126},
#  {'label': 'positive', 'score': 0.8217071890830994},
#  {'label': 'negative', 'score': 0.9851463437080383},
#  {'label': 'negative', 'score': 0.9945122003555298},
#  {'label': 'negative', 'score': 0.9258331060409546},
#  {'label': 'negative', 'score': 0.9943177103996277},
#  {'label': 'positive', 'score': 0.9619539976119995},
#  {'label': 'negative', 'score': 0.9874531626701355},
#  {'label': 'negative', 'score': 0.7606571912765503},
#  {'label': 'negative', 'score': 0.9946700930595398},
#  {'label': 'negative', 'score': 0.8399326205253601},
#  {'label': 'negative', 'score': 0.9941809773445129},
#  {'label': 'negative', 'score': 0.97614985704422},
#  {'label': 'negative', 'score': 0.9865186810493469},
#  {'label': 'neutral', 'score': 0.9898107051849365},
#  {'label': 'negative', 'score': 0.99234938621521},
#  {'label': 'negative', 'score': 0.971509575843811},
#  {'label': 'negative', 'score': 0.9785522818565369},
#  {'label': 'negative', 'score': 0.9946900606155396},
#  {'label': 'neutral', 'score': 0.9696020483970642},
#  {'label': 'negative', 'score': 0.9964414238929749},
#  {'label': 'negative', 'score': 0.9890910983085632},
#  {'label': 'negative', 'score': 0.9963059425354004},
#  {'label': 'neutral', 'score': 0.951596736907959},
#  {'label': 'neutral', 'score': 0.9797976613044739},
#  {'label': 'neutral', 'score': 0.9327624440193176},
#  {'label': 'negative', 'score': 0.9960790276527405},
#  {'label': 'negative', 'score': 0.9890341758728027},
#  {'label': 'positive', 'score': 0.9590741395950317},
#  {'label': 'negative', 'score': 0.9699021577835083},
#  {'label': 'negative', 'score': 0.9966532588005066},
#  {'label': 'negative', 'score': 0.9001954197883606},
#  {'label': 'neutral', 'score': 0.987908661365509},
#  {'label': 'negative', 'score': 0.9939633011817932},
#  {'label': 'negative', 'score': 0.9955435395240784},
#  {'label': 'neutral', 'score': 0.6823045015335083},
#  {'label': 'negative', 'score': 0.9662173390388489},
#  {'label': 'neutral', 'score': 0.9684996008872986},
#  {'label': 'negative', 'score': 0.8943779468536377},
#  {'label': 'negative', 'score': 0.907468318939209},
#  {'label': 'negative', 'score': 0.9542008638381958},
#  {'label': 'negative', 'score': 0.7794100642204285},
#  {'label': 'negative', 'score': 0.9964452385902405},
#  {'label': 'neutral', 'score': 0.9767529368400574},
#  {'label': 'negative', 'score': 0.9962819218635559},
#  {'label': 'negative', 'score': 0.7060360312461853},
#  {'label': 'positive', 'score': 0.9752151966094971},
#  {'label': 'negative', 'score': 0.9929793477058411},
#  {'label': 'positive', 'score': 0.9788963198661804},
#  {'label': 'neutral', 'score': 0.9775490164756775},
#  {'label': 'positive', 'score': 0.9551863670349121},
#  {'label': 'negative', 'score': 0.525343120098114},
#  {'label': 'negative', 'score': 0.9950376152992249},
#  {'label': 'negative', 'score': 0.9139206409454346},
#  {'label': 'neutral', 'score': 0.8579915165901184},
#  {'label': 'positive', 'score': 0.8431257605552673},
#  {'label': 'negative', 'score': 0.9078783392906189},
#  {'label': 'negative', 'score': 0.9962839484214783},
#  {'label': 'negative', 'score': 0.94740229845047},
#  {'label': 'positive', 'score': 0.9287728071212769},
#  {'label': 'neutral', 'score': 0.9780709147453308},
#  {'label': 'negative', 'score': 0.9953462481498718},
#  {'label': 'neutral', 'score': 0.9912821054458618},
#  {'label': 'neutral', 'score': 0.6835544109344482},
#  {'label': 'positive', 'score': 0.8995944261550903},
#  {'label': 'negative', 'score': 0.9782957434654236},
#  {'label': 'negative', 'score': 0.9958349466323853},
#  {'label': 'negative', 'score': 0.9914632439613342},
#  {'label': 'negative', 'score': 0.984271228313446},
#  {'label': 'positive', 'score': 0.8951817154884338},
#  {'label': 'negative', 'score': 0.9956437349319458},
#  {'label': 'positive', 'score': 0.7355230450630188},
#  {'label': 'negative', 'score': 0.9966214895248413},
#  {'label': 'negative', 'score': 0.996357262134552},
#  {'label': 'positive', 'score': 0.9709475040435791},
#  {'label': 'negative', 'score': 0.6600003242492676},
#  {'label': 'neutral', 'score': 0.9839831590652466},
#  {'label': 'negative', 'score': 0.9943532943725586},
#  {'label': 'neutral', 'score': 0.7347638607025146},
#  {'label': 'neutral', 'score': 0.9850733876228333},
#  {'label': 'neutral', 'score': 0.9405015707015991},
#  {'label': 'negative', 'score': 0.9956845045089722},
#  {'label': 'negative', 'score': 0.9817843437194824},
#  {'label': 'neutral', 'score': 0.9097415804862976},
#  {'label': 'negative', 'score': 0.9949139356613159},
#  {'label': 'negative', 'score': 0.9936530590057373},
#  {'label': 'positive', 'score': 0.6894791126251221},
#  {'label': 'negative', 'score': 0.889607846736908},
#  {'label': 'neutral', 'score': 0.6975610852241516},
#  {'label': 'negative', 'score': 0.9357997179031372},
#  {'label': 'positive', 'score': 0.9370524883270264},
#  {'label': 'negative', 'score': 0.9915847778320312},
#  {'label': 'negative', 'score': 0.9967886209487915},
#  {'label': 'negative', 'score': 0.9963682889938354},
#  {'label': 'negative', 'score': 0.9844216108322144},
#  {'label': 'negative', 'score': 0.9873145222663879},
#  {'label': 'negative', 'score': 0.9967374205589294},
#  {'label': 'negative', 'score': 0.9964421391487122},
#  {'label': 'negative', 'score': 0.9959806203842163},
#  {'label': 'negative', 'score': 0.9930787682533264},
#  {'label': 'negative', 'score': 0.9968999624252319},
#  {'label': 'neutral', 'score': 0.9401169419288635},
#  {'label': 'negative', 'score': 0.9764165282249451},
#  {'label': 'negative', 'score': 0.9910452961921692},
#  {'label': 'negative', 'score': 0.9090366363525391},
#  {'label': 'negative', 'score': 0.5945358276367188},
#  {'label': 'neutral', 'score': 0.9444596171379089},
#  {'label': 'negative', 'score': 0.9933205842971802},
#  {'label': 'positive', 'score': 0.827701210975647},
#  {'label': 'negative', 'score': 0.9826069474220276},
#  {'label': 'negative', 'score': 0.9956786036491394},
#  {'label': 'neutral', 'score': 0.9297866821289062},
#  {'label': 'negative', 'score': 0.9824243187904358},
#  {'label': 'neutral', 'score': 0.9242327213287354},
#  {'label': 'positive', 'score': 0.9155290126800537},
#  {'label': 'neutral', 'score': 0.5065374970436096},
#  {'label': 'positive', 'score': 0.8965134024620056},
#  {'label': 'negative', 'score': 0.4735638201236725},
#  {'label': 'positive', 'score': 0.8680513501167297},
#  {'label': 'negative', 'score': 0.9940945506095886},
#  {'label': 'negative', 'score': 0.829881489276886},
#  {'label': 'negative', 'score': 0.9962612986564636},
#  {'label': 'positive', 'score': 0.922327995300293},
#  {'label': 'negative', 'score': 0.9952056407928467},
#  {'label': 'neutral', 'score': 0.8044673204421997},
#  {'label': 'negative', 'score': 0.9957714676856995},
#  {'label': 'negative', 'score': 0.9876790642738342},
#  {'label': 'negative', 'score': 0.9926878213882446},
#  {'label': 'negative', 'score': 0.9965797066688538},
#  {'label': 'positive', 'score': 0.9618876576423645},
#  {'label': 'negative', 'score': 0.9955785870552063},
#  {'label': 'neutral', 'score': 0.6924519538879395},
#  {'label': 'neutral', 'score': 0.9725396633148193},
#  {'label': 'negative', 'score': 0.9958749413490295},
#  {'label': 'negative', 'score': 0.9966709017753601},
#  {'label': 'negative', 'score': 0.9911841750144958},
#  {'label': 'negative', 'score': 0.9951935410499573},
#  {'label': 'negative', 'score': 0.9963095784187317},
#  {'label': 'negative', 'score': 0.9953175783157349},
#  {'label': 'positive', 'score': 0.9737686514854431},
#  {'label': 'positive', 'score': 0.911841094493866},
#  {'label': 'negative', 'score': 0.9909720420837402},
#  {'label': 'negative', 'score': 0.769366979598999},
#  {'label': 'negative', 'score': 0.9902752637863159},
#  {'label': 'negative', 'score': 0.9943739175796509},
#  {'label': 'negative', 'score': 0.995398223400116},
#  {'label': 'negative', 'score': 0.9967958331108093},
#  {'label': 'positive', 'score': 0.9718681573867798},
#  {'label': 'negative', 'score': 0.8019924759864807},
#  {'label': 'negative', 'score': 0.9949392080307007},
#  {'label': 'positive', 'score': 0.9764329791069031},
#  {'label': 'negative', 'score': 0.9034828543663025},
#  {'label': 'negative', 'score': 0.9528610110282898},
#  {'label': 'negative', 'score': 0.9959535598754883},
#  {'label': 'negative', 'score': 0.8541262745857239},
#  {'label': 'positive', 'score': 0.9265865087509155},
#  {'label': 'negative', 'score': 0.9900395274162292},
#  {'label': 'neutral', 'score': 0.9490528702735901},
#  {'label': 'negative', 'score': 0.9930734038352966},
#  {'label': 'negative', 'score': 0.9959892630577087},
#  {'label': 'positive', 'score': 0.9774551391601562},
#  {'label': 'positive', 'score': 0.9591143727302551},
#  {'label': 'negative', 'score': 0.9014665484428406},
#  {'label': 'negative', 'score': 0.9825248122215271},
#  {'label': 'negative', 'score': 0.9952724575996399},
#  {'label': 'neutral', 'score': 0.9811357855796814},
#  {'label': 'positive', 'score': 0.8806980848312378},
#  {'label': 'neutral', 'score': 0.9820170998573303},
#  {'label': 'negative', 'score': 0.9925049543380737},
#  {'label': 'neutral', 'score': 0.9684901237487793},
#  {'label': 'negative', 'score': 0.6545753479003906},
#  {'label': 'neutral', 'score': 0.9586265087127686},
#  {'label': 'negative', 'score': 0.7314725518226624},
#  {'label': 'negative', 'score': 0.9931625127792358},
#  {'label': 'negative', 'score': 0.9836108684539795},
#  {'label': 'negative', 'score': 0.9950226545333862},
#  {'label': 'negative', 'score': 0.9907588958740234},
#  {'label': 'negative', 'score': 0.9911264777183533},
#  {'label': 'neutral', 'score': 0.5045587420463562},
#  {'label': 'negative', 'score': 0.9956177473068237},
#  {'label': 'negative', 'score': 0.9932090640068054},
#  {'label': 'neutral', 'score': 0.8774632215499878},
#  {'label': 'negative', 'score': 0.9927281141281128},
#  {'label': 'negative', 'score': 0.99578458070755},
#  {'label': 'positive', 'score': 0.8155902028083801},
#  {'label': 'negative', 'score': 0.765576183795929},
#  {'label': 'negative', 'score': 0.9648914337158203},
#  {'label': 'neutral', 'score': 0.9847955703735352},
#  {'label': 'positive', 'score': 0.8070660829544067},
#  {'label': 'negative', 'score': 0.9949997663497925},
#  {'label': 'positive', 'score': 0.5390565395355225},
#  {'label': 'negative', 'score': 0.9949302077293396},
#  {'label': 'negative', 'score': 0.99400395154953},
#  {'label': 'negative', 'score': 0.9940449595451355},
#  {'label': 'negative', 'score': 0.9954191446304321},
#  {'label': 'negative', 'score': 0.9889042973518372},
#  {'label': 'neutral', 'score': 0.9913814663887024},
#  {'label': 'positive', 'score': 0.9802851676940918},
#  {'label': 'positive', 'score': 0.9067645072937012},
#  {'label': 'negative', 'score': 0.9948157668113708},
#  {'label': 'negative', 'score': 0.9867383241653442},
#  {'label': 'neutral', 'score': 0.8015019297599792},
#  {'label': 'neutral', 'score': 0.9855205416679382},
#  {'label': 'negative', 'score': 0.9930949211120605},
#  {'label': 'neutral', 'score': 0.9759294986724854},
#  {'label': 'positive', 'score': 0.8477036356925964},
#  {'label': 'neutral', 'score': 0.9646254777908325},
#  {'label': 'negative', 'score': 0.9940535426139832},
#  {'label': 'negative', 'score': 0.979212760925293},
#  {'label': 'negative', 'score': 0.9947046637535095},
#  {'label': 'negative', 'score': 0.9937513470649719},
#  {'label': 'neutral', 'score': 0.8776205778121948},
#  {'label': 'negative', 'score': 0.994500994682312},
#  {'label': 'neutral', 'score': 0.7894800305366516},
#  {'label': 'positive', 'score': 0.6086261868476868},
#  {'label': 'positive', 'score': 0.8401599526405334},
#  {'label': 'negative', 'score': 0.9961447715759277},
#  {'label': 'negative', 'score': 0.9959474205970764},
#  {'label': 'neutral', 'score': 0.9252787828445435},
#  {'label': 'negative', 'score': 0.5333803296089172},
#  {'label': 'neutral', 'score': 0.990617573261261},
#  {'label': 'negative', 'score': 0.9959129691123962},
#  {'label': 'negative', 'score': 0.9751994609832764},
#  {'label': 'negative', 'score': 0.9952996969223022},
#  {'label': 'negative', 'score': 0.9956859350204468},
#  {'label': 'negative', 'score': 0.996650755405426},
#  {'label': 'neutral', 'score': 0.958921492099762},
#  {'label': 'negative', 'score': 0.994346559047699},
#  {'label': 'negative', 'score': 0.8414825797080994},
#  {'label': 'positive', 'score': 0.9327707886695862},
#  {'label': 'negative', 'score': 0.984286904335022},
#  {'label': 'negative', 'score': 0.9918060302734375},
#  {'label': 'negative', 'score': 0.9826260805130005},
#  {'label': 'negative', 'score': 0.9963076114654541},
#  {'label': 'neutral', 'score': 0.7869164347648621},
#  {'label': 'positive', 'score': 0.945245623588562},
#  {'label': 'neutral', 'score': 0.9269018173217773},
#  {'label': 'positive', 'score': 0.9424446225166321},
#  {'label': 'negative', 'score': 0.9779462814331055},
#  {'label': 'negative', 'score': 0.9965830445289612},
#  {'label': 'neutral', 'score': 0.7237063050270081},
#  {'label': 'negative', 'score': 0.9723793864250183},
#  {'label': 'negative', 'score': 0.9964889287948608},
#  {'label': 'positive', 'score': 0.976242184638977},
#  {'label': 'negative', 'score': 0.9953566193580627},
#  {'label': 'negative', 'score': 0.9959263801574707},
#  {'label': 'negative', 'score': 0.6713493466377258},
#  {'label': 'positive', 'score': 0.6693834662437439},
#  {'label': 'negative', 'score': 0.9944753050804138},
#  {'label': 'negative', 'score': 0.9958716034889221},
#  {'label': 'neutral', 'score': 0.9244359135627747},
#  {'label': 'positive', 'score': 0.9553053379058838},
#  {'label': 'negative', 'score': 0.9959288239479065},
#  {'label': 'negative', 'score': 0.9640495777130127},
#  {'label': 'negative', 'score': 0.9542253017425537},
#  {'label': 'neutral', 'score': 0.9161564707756042},
#  {'label': 'negative', 'score': 0.9868865609169006},
#  {'label': 'negative', 'score': 0.720409095287323},
#  {'label': 'negative', 'score': 0.9747006297111511},
#  {'label': 'negative', 'score': 0.995945155620575},
#  {'label': 'neutral', 'score': 0.7760134935379028},
#  {'label': 'positive', 'score': 0.9503011703491211},
#  {'label': 'neutral', 'score': 0.9901808500289917},
#  {'label': 'negative', 'score': 0.9938165545463562},
#  {'label': 'negative', 'score': 0.996573805809021},
#  {'label': 'negative', 'score': 0.54042649269104},
#  {'label': 'negative', 'score': 0.9962408542633057},
#  {'label': 'negative', 'score': 0.9928528666496277},
#  {'label': 'negative', 'score': 0.9961254000663757},
#  {'label': 'positive', 'score': 0.7157642245292664},
#  {'label': 'neutral', 'score': 0.9751778841018677},
#  {'label': 'neutral', 'score': 0.966611921787262},
#  {'label': 'negative', 'score': 0.9932767152786255},
#  {'label': 'neutral', 'score': 0.9377062916755676},
#  {'label': 'positive', 'score': 0.5137681365013123},
#  {'label': 'negative', 'score': 0.9946591258049011},
#  {'label': 'negative', 'score': 0.9971005320549011},
#  {'label': 'negative', 'score': 0.9963490962982178},
#  {'label': 'negative', 'score': 0.9962599277496338},
#  {'label': 'neutral', 'score': 0.9106109142303467},
#  {'label': 'neutral', 'score': 0.8706804513931274},
#  {'label': 'negative', 'score': 0.995183527469635},
#  {'label': 'negative', 'score': 0.9843034744262695},
#  {'label': 'negative', 'score': 0.9684190154075623},
#  {'label': 'neutral', 'score': 0.8782739639282227},
#  {'label': 'negative', 'score': 0.9887358546257019},
#  {'label': 'neutral', 'score': 0.6494828462600708},
#  {'label': 'negative', 'score': 0.9958354234695435},
#  {'label': 'negative', 'score': 0.43001869320869446},
#  {'label': 'negative', 'score': 0.9952316880226135},
#  {'label': 'negative', 'score': 0.9242019653320312},
#  {'label': 'negative', 'score': 0.9276958107948303},
#  {'label': 'positive', 'score': 0.965449333190918},
#  {'label': 'negative', 'score': 0.7055402398109436},
#  {'label': 'negative', 'score': 0.8967105746269226},
#  {'label': 'positive', 'score': 0.951483428478241},
#  {'label': 'neutral', 'score': 0.9710949063301086},
#  {'label': 'negative', 'score': 0.994690477848053},
#  {'label': 'negative', 'score': 0.9953084588050842},
#  {'label': 'positive', 'score': 0.6246380805969238},
#  {'label': 'negative', 'score': 0.9965987801551819},
#  {'label': 'negative', 'score': 0.9886179566383362},
#  {'label': 'negative', 'score': 0.9954153299331665},
#  {'label': 'negative', 'score': 0.968296468257904},
#  {'label': 'negative', 'score': 0.9955089092254639},
#  {'label': 'negative', 'score': 0.9945869445800781},
#  {'label': 'neutral', 'score': 0.9599067568778992},
#  {'label': 'neutral', 'score': 0.4661557674407959},
#  {'label': 'neutral', 'score': 0.9763437509536743},
#  {'label': 'negative', 'score': 0.9877040386199951},
#  {'label': 'positive', 'score': 0.6485773324966431},
#  {'label': 'negative', 'score': 0.9964253306388855},
#  {'label': 'negative', 'score': 0.991060197353363},
#  {'label': 'negative', 'score': 0.9964697360992432},
#  {'label': 'negative', 'score': 0.9920310974121094},
#  {'label': 'negative', 'score': 0.7202540636062622},
#  {'label': 'negative', 'score': 0.9924877882003784},
#  {'label': 'negative', 'score': 0.9862122535705566},
#  {'label': 'positive', 'score': 0.37746402621269226},
#  {'label': 'neutral', 'score': 0.6633346080780029},
#  {'label': 'neutral', 'score': 0.9759703874588013},
#  {'label': 'positive', 'score': 0.9463220834732056},
#  {'label': 'negative', 'score': 0.974837601184845},
#  {'label': 'positive', 'score': 0.9689440727233887},
#  {'label': 'positive', 'score': 0.9721332788467407},
#  {'label': 'positive', 'score': 0.5789706110954285},
#  {'label': 'positive', 'score': 0.9678356647491455},
#  {'label': 'negative', 'score': 0.8744149208068848},
#  {'label': 'negative', 'score': 0.9961276650428772},
#  {'label': 'negative', 'score': 0.9959934949874878},
#  {'label': 'negative', 'score': 0.9959661960601807},
#  {'label': 'positive', 'score': 0.9572166204452515},
#  {'label': 'positive', 'score': 0.9728030562400818},
#  {'label': 'negative', 'score': 0.9948837161064148},
#  {'label': 'negative', 'score': 0.9507856965065002},
#  {'label': 'negative', 'score': 0.9926671385765076},
#  {'label': 'negative', 'score': 0.9958327412605286},
#  {'label': 'neutral', 'score': 0.8939548134803772},
#  {'label': 'positive', 'score': 0.9696077704429626},
#  {'label': 'negative', 'score': 0.7461627721786499},
#  {'label': 'negative', 'score': 0.5951958894729614},
#  {'label': 'negative', 'score': 0.7966679334640503},
#  {'label': 'negative', 'score': 0.9964014291763306},
#  {'label': 'negative', 'score': 0.8144208192825317},
#  {'label': 'negative', 'score': 0.9161282181739807},
#  {'label': 'negative', 'score': 0.9610700607299805},
#  {'label': 'negative', 'score': 0.9942130446434021},
#  {'label': 'positive', 'score': 0.968789279460907},
#  {'label': 'positive', 'score': 0.9242568612098694},
#  {'label': 'negative', 'score': 0.9592139720916748},
#  {'label': 'neutral', 'score': 0.8758836984634399},
#  {'label': 'negative', 'score': 0.9263672828674316},
#  {'label': 'negative', 'score': 0.9746954441070557},
#  {'label': 'negative', 'score': 0.6964341998100281},
#  {'label': 'negative', 'score': 0.8246647119522095},
#  {'label': 'negative', 'score': 0.9933722019195557},
#  {'label': 'negative', 'score': 0.9635019302368164},
#  {'label': 'negative', 'score': 0.9866880774497986},
#  {'label': 'negative', 'score': 0.8028467893600464},
#  {'label': 'negative', 'score': 0.994944155216217},
#  {'label': 'positive', 'score': 0.907196581363678},
#  {'label': 'negative', 'score': 0.9001149535179138},
#  {'label': 'negative', 'score': 0.9837856888771057},
#  {'label': 'negative', 'score': 0.9949690699577332},
#  {'label': 'positive', 'score': 0.8466271758079529},
#  {'label': 'negative', 'score': 0.9637571573257446},
#  {'label': 'negative', 'score': 0.9927305579185486},
#  {'label': 'neutral', 'score': 0.5219060182571411},
#  {'label': 'negative', 'score': 0.9848904013633728},
#  {'label': 'negative', 'score': 0.9213933944702148},
#  {'label': 'neutral', 'score': 0.9782356023788452},
#  {'label': 'neutral', 'score': 0.9779475331306458},
#  {'label': 'negative', 'score': 0.9900888800621033},
#  {'label': 'negative', 'score': 0.9782094955444336},
#  {'label': 'negative', 'score': 0.9614652991294861},
#  {'label': 'positive', 'score': 0.9823434352874756},
#  {'label': 'negative', 'score': 0.5692760944366455},
#  {'label': 'negative', 'score': 0.9814727306365967},
#  {'label': 'neutral', 'score': 0.630754828453064},
#  {'label': 'negative', 'score': 0.9966022968292236},
#  {'label': 'negative', 'score': 0.996793806552887},
#  {'label': 'negative', 'score': 0.990570068359375},
#  {'label': 'negative', 'score': 0.9959263801574707},
#  {'label': 'neutral', 'score': 0.6067742705345154},
#  {'label': 'negative', 'score': 0.9804285168647766},
#  {'label': 'negative', 'score': 0.9954652190208435},
#  {'label': 'positive', 'score': 0.9350829124450684},
#  {'label': 'negative', 'score': 0.9945489764213562},
#  {'label': 'neutral', 'score': 0.4592508375644684},
#  {'label': 'negative', 'score': 0.9449462294578552},
#  {'label': 'negative', 'score': 0.7479589581489563},
#  {'label': 'neutral', 'score': 0.9664719104766846},
#  {'label': 'positive', 'score': 0.9794339537620544},
#  {'label': 'neutral', 'score': 0.9900450110435486},
#  {'label': 'negative', 'score': 0.477438360452652},
#  {'label': 'neutral', 'score': 0.7442197203636169},
#  {'label': 'neutral', 'score': 0.9390354156494141},
#  {'label': 'positive', 'score': 0.8909426331520081},
#  {'label': 'negative', 'score': 0.9962365031242371},
#  {'label': 'neutral', 'score': 0.957124650478363},
#  {'label': 'neutral', 'score': 0.9430620074272156},
#  {'label': 'negative', 'score': 0.987984299659729},
#  {'label': 'negative', 'score': 0.760617733001709},
#  {'label': 'negative', 'score': 0.9943055510520935},
#  {'label': 'neutral', 'score': 0.9146054983139038},
#  {'label': 'negative', 'score': 0.995305061340332},
#  {'label': 'neutral', 'score': 0.8826578259468079},
#  {'label': 'positive', 'score': 0.8660712838172913},
#  {'label': 'negative', 'score': 0.9959918856620789},
#  {'label': 'negative', 'score': 0.7564722299575806},
#  {'label': 'negative', 'score': 0.9947552680969238},
#  {'label': 'negative', 'score': 0.9965366125106812},
#  {'label': 'neutral', 'score': 0.9908210635185242},
#  {'label': 'neutral', 'score': 0.9318356513977051},
#  {'label': 'negative', 'score': 0.5388110876083374},
#  {'label': 'negative', 'score': 0.99382084608078},
#  {'label': 'negative', 'score': 0.9956393241882324},
#  {'label': 'negative', 'score': 0.9944412112236023},
#  {'label': 'positive', 'score': 0.9730303883552551},
#  {'label': 'positive', 'score': 0.956034243106842},
#  {'label': 'negative', 'score': 0.9892815351486206},
#  {'label': 'positive', 'score': 0.9252491593360901},
#  {'label': 'neutral', 'score': 0.9885953068733215},
#  {'label': 'negative', 'score': 0.5543776154518127},
#  {'label': 'negative', 'score': 0.9964144229888916},
#  {'label': 'negative', 'score': 0.9643614292144775},
#  {'label': 'neutral', 'score': 0.9550968408584595},
#  {'label': 'positive', 'score': 0.9445310831069946},
#  {'label': 'negative', 'score': 0.9954634308815002},
#  {'label': 'negative', 'score': 0.9962413311004639},
#  {'label': 'negative', 'score': 0.9959806203842163},
#  {'label': 'positive', 'score': 0.9846788644790649},
#  {'label': 'neutral', 'score': 0.9530569314956665},
#  {'label': 'negative', 'score': 0.9960766434669495},
#  {'label': 'negative', 'score': 0.9904283285140991},
#  {'label': 'negative', 'score': 0.996579110622406},
#  {'label': 'negative', 'score': 0.9910182952880859},
#  {'label': 'negative', 'score': 0.9621670246124268},
#  {'label': 'negative', 'score': 0.9859892129898071},
#  {'label': 'neutral', 'score': 0.9859232902526855},
#  {'label': 'positive', 'score': 0.9537389278411865},
#  {'label': 'negative', 'score': 0.9289802312850952},
#  {'label': 'negative', 'score': 0.9434354305267334},
#  {'label': 'negative', 'score': 0.9967288970947266},
#  {'label': 'negative', 'score': 0.9702455401420593},
#  {'label': 'neutral', 'score': 0.9902163743972778},
#  {'label': 'negative', 'score': 0.947733461856842},
#  {'label': 'positive', 'score': 0.9555916786193848},
#  {'label': 'negative', 'score': 0.9957004189491272},
#  {'label': 'negative', 'score': 0.579735517501831},
#  {'label': 'positive', 'score': 0.9043245911598206},
#  {'label': 'negative', 'score': 0.9964492321014404},
#  {'label': 'positive', 'score': 0.9149140119552612},
#  {'label': 'negative', 'score': 0.9963318705558777},
#  {'label': 'negative', 'score': 0.9960693120956421},
#  {'label': 'negative', 'score': 0.9960611462593079},
#  {'label': 'negative', 'score': 0.9964017868041992},
#  {'label': 'negative', 'score': 0.9269630908966064},
#  {'label': 'positive', 'score': 0.9857317805290222},
#  {'label': 'neutral', 'score': 0.7755202651023865},
#  {'label': 'negative', 'score': 0.8611047863960266},
#  {'label': 'negative', 'score': 0.9923995137214661},
#  {'label': 'negative', 'score': 0.9949501752853394},
#  {'label': 'negative', 'score': 0.7263330817222595},
#  {'label': 'negative', 'score': 0.9959776997566223},
#  {'label': 'negative', 'score': 0.9966756105422974},
#  {'label': 'negative', 'score': 0.9963464140892029},
#  {'label': 'negative', 'score': 0.9696688055992126},
#  {'label': 'negative', 'score': 0.9937373399734497},
#  {'label': 'neutral', 'score': 0.990581214427948},
#  {'label': 'neutral', 'score': 0.7141227126121521},
#  {'label': 'negative', 'score': 0.9914836287498474},
#  {'label': 'negative', 'score': 0.8085588216781616},
#  {'label': 'negative', 'score': 0.8138701319694519},
#  {'label': 'negative', 'score': 0.9886136054992676},
#  {'label': 'neutral', 'score': 0.920737087726593},
#  {'label': 'negative', 'score': 0.9963458180427551},
#  {'label': 'negative', 'score': 0.9762459397315979},
#  {'label': 'negative', 'score': 0.9792575240135193},
#  {'label': 'positive', 'score': 0.9617601633071899},
#  {'label': 'negative', 'score': 0.9918166995048523},
#  {'label': 'negative', 'score': 0.9951017498970032},
#  {'label': 'negative', 'score': 0.9945734143257141},
#  {'label': 'positive', 'score': 0.8096123337745667},
#  {'label': 'negative', 'score': 0.9413019418716431},
#  {'label': 'positive', 'score': 0.9680479764938354},
#  {'label': 'negative', 'score': 0.9956877827644348},
#  {'label': 'negative', 'score': 0.6774293780326843},
#  {'label': 'negative', 'score': 0.9908432960510254},
#  {'label': 'neutral', 'score': 0.9911441802978516},
#  {'label': 'negative', 'score': 0.9922115802764893},
#  {'label': 'negative', 'score': 0.996610701084137},
#  {'label': 'neutral', 'score': 0.9664453864097595},
#  {'label': 'negative', 'score': 0.9897294044494629},
#  {'label': 'negative', 'score': 0.9961044788360596},
#  {'label': 'negative', 'score': 0.9962233304977417},
#  {'label': 'positive', 'score': 0.9725111722946167},
#  {'label': 'negative', 'score': 0.9926782846450806},
#  {'label': 'negative', 'score': 0.8597338199615479},
#  {'label': 'negative', 'score': 0.9876163601875305},
#  {'label': 'negative', 'score': 0.7452636361122131},
#  ...]

# %% [markdown]
# END
