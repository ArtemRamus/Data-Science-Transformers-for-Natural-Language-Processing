# %%
# !pip install transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 22.2 MB/s
# Collecting datasets
#   Downloading datasets-2.7.1-py3-none-any.whl (451 kB)
#      |████████████████████████████████| 451 kB 67.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 61.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 70.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 7.6 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 70.2 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 60.8 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, tokenizers, responses, multiprocess, huggingface-hub, transformers, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.7.1 huggingface-hub-0.11.1 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.25.1 urllib3-1.25.11 xxhash-3.1.0

# %%
# https://www.kaggle.com/crowdflower/twitter-airline-sentiment
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# --2022-12-09 09:12:57--  https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3421431 (3.3M) [text/csv]
# Saving to: ‘AirlineTweets.csv’
#
# AirlineTweets.csv   100%[===================>]   3.26M  1.30MB/s    in 2.5s
#
# 2022-12-09 09:13:01 (1.30 MB/s) - ‘AirlineTweets.csv’ saved [3421431/3421431]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

import torch

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("AirlineTweets.csv")

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df = df[['airline_sentiment', 'text']].copy()

# %%
df.head()
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
df.airline_sentiment.hist()

# %%
target_map = {'positive': 1, 'negative': 0, 'neutral': 2}
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df2 = df[['text', 'target']]
df2.columns = ['sentence', 'label']
df2.to_csv('data.csv', index=None)

# %%
# !head data.csv
# Out:
# sentence,label
# @VirginAmerica What @dhepburn said.,2
# @VirginAmerica plus you've added commercials to the experience... tacky.,1
# @VirginAmerica I didn't today... Must mean I need to take another trip!,2
# "@VirginAmerica it's really aggressive to blast obnoxious ""entertainment"" in your guests' faces &amp; they have little recourse",0
# @VirginAmerica and it's a really big bad thing about it,0
# "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.
# it's really the only bad thing about flying VA",0
# "@VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)",1
# "@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP",2

# %%
from datasets import load_dataset
raw_dataset = load_dataset('csv', data_files='data.csv')
# Out:
# WARNING:datasets.builder:Using custom data configuration default-08a229ef8b9c4e5b
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-08a229ef8b9c4e5b/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-08a229ef8b9c4e5b/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 14640
#     })
# })

# %%
split = raw_dataset['train'].train_test_split(test_size=.3, seed=42)

# %%
split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 10248
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 4392
#     })
# })

# %%
# if there are multinle csv files
# load_dataset('csv',  data_files=['file1.csv', 'file2.csv'])

# %%
# if there is already train test split
# load_dataset('csv',  data_files={
#                                   'train': ['file1.csv', 'file2.csv'],
#                                   'test': 'test.csv'
#                                  })

# %%
checkpoint = 'distilbert-base-cased'

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/411 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
def tokenize_fn(batch):
    return tokenizer(batch['sentence'], truncation=True)

# %%
tokenized_datasets = split.map(tokenize_fn, batched=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?ba/s]
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %%
from transformers import AutoModelForSequenceClassification, \
    Trainer, TrainingArguments

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    checkpoint, num_labels=3)
# Out:
# Downloading:   0%|          | 0.00/263M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['pre_classifier.bias', 'classifier.bias', 'classifier.weight', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !pip install torchinfo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.1-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.1

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DistilBertForSequenceClassification                     --
# ├─DistilBertModel: 1-1                                  --
# │    └─Embeddings: 2-1                                  --
# │    │    └─Embedding: 3-1                              22,268,928
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─LayerNorm: 3-3                              1,536
# │    │    └─Dropout: 3-4                                --
# │    └─Transformer: 2-2                                 --
# │    │    └─ModuleList: 3-5                             42,527,232
# ├─Linear: 1-2                                           590,592
# ├─Linear: 1-3                                           2,307
# ├─Dropout: 1-4                                          --
# ================================================================================
# Total params: 65,783,811
# Trainable params: 65,783,811
# Non-trainable params: 0
# ================================================================================

# %%
training_args = TrainingArguments(
    output_dir='training_dir',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64
)

# %%
def compute_metrics(logits_and_labels):
    logits, labels = logits_and_labels
    predictions = np.argmax(logits, axis=-1)
    acc = np.mean(predictions==labels)
    f1 = f1_score(labels, predictions, average='macro') 
    return {'accuracy': acc, 'f1': f1}

# %%
trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 10248
#   Num Epochs = 3
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1923
#   Number of trainable parameters = 65783811
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1923' max='1923' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1923/1923 03:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.544500</td>
#       <td>0.428623</td>
#       <td>0.829918</td>
#       <td>0.779182</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.346600</td>
#       <td>0.467255</td>
#       <td>0.836749</td>
#       <td>0.792943</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.241900</td>
#       <td>0.607555</td>
#       <td>0.841985</td>
#       <td>0.789696</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-641
# Configuration saved in training_dir/checkpoint-641/config.json
# Model weights saved in training_dir/checkpoint-641/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-641/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-641/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-1282
# Configuration saved in training_dir/checkpoint-1282/config.json
# Model weights saved in training_dir/checkpoint-1282/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-1282/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-1282/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: sentence. If sentence are not expected by `DistilBertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 4392
#   Batch size = 64
# Saving model checkpoint to training_dir/checkpoint-1923
# Configuration saved in training_dir/checkpoint-1923/config.json
# Model weights saved in training_dir/checkpoint-1923/pytorch_model.bin
# tokenizer config file saved in training_dir/checkpoint-1923/tokenizer_config.json
# Special tokens file saved in training_dir/checkpoint-1923/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=1923, training_loss=0.3295422740981905, metrics={'train_runtime': 215.6475, 'train_samples_per_second': 142.566, 'train_steps_per_second': 8.917, 'total_flos': 388376501242176.0, 'train_loss': 0.3295422740981905, 'epoch': 3.0})

# %%
# !ls training_dir
# Out:
# checkpoint-1282  checkpoint-1923  checkpoint-641  runs

# %%
from transformers import pipeline

# %%
savedmodel = pipeline('text-classification',
                      model='training_dir/checkpoint-1282',
                      device=0)
# Out:
# loading configuration file training_dir/checkpoint-1282/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "training_dir/checkpoint-1282",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "vocab_size": 28996
# }
#
# loading configuration file training_dir/checkpoint-1282/config.json
# Model config DistilBertConfig {
#   "_name_or_path": "training_dir/checkpoint-1282",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForSequenceClassification"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "initializer_range": 0.02,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "problem_type": "single_label_classification",
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "vocab_size": 28996
# }
#
# loading weights file training_dir/checkpoint-1282/pytorch_model.bin
# All model checkpoint weights were used when initializing DistilBertForSequenceClassification.
#
# All the weights of DistilBertForSequenceClassification were initialized from the model checkpoint at training_dir/checkpoint-1282.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForSequenceClassification for predictions without further training.
# loading file vocab.txt
# loading file tokenizer.json
# loading file added_tokens.json
# loading file special_tokens_map.json
# loading file tokenizer_config.json

# %%
split['test']
# Out:
# Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 4392
# })

# %%
test_pred = savedmodel(split['test']['sentence'])
# Out:
# Disabling tokenizer parallelism, we're using DataLoader multithreading already

# %%
test_pred
# Out:
# [{'label': 'LABEL_1', 'score': 0.9040488600730896},
#  {'label': 'LABEL_1', 'score': 0.9342843294143677},
#  {'label': 'LABEL_1', 'score': 0.49297961592674255},
#  {'label': 'LABEL_1', 'score': 0.890904426574707},
#  {'label': 'LABEL_2', 'score': 0.6808640956878662},
#  {'label': 'LABEL_0', 'score': 0.9939355254173279},
#  {'label': 'LABEL_2', 'score': 0.930452287197113},
#  {'label': 'LABEL_2', 'score': 0.9640214443206787},
#  {'label': 'LABEL_2', 'score': 0.6237916350364685},
#  {'label': 'LABEL_0', 'score': 0.9945341348648071},
#  {'label': 'LABEL_0', 'score': 0.9354149699211121},
#  {'label': 'LABEL_0', 'score': 0.9851781725883484},
#  {'label': 'LABEL_1', 'score': 0.9328517913818359},
#  {'label': 'LABEL_0', 'score': 0.9855318665504456},
#  {'label': 'LABEL_2', 'score': 0.9789638519287109},
#  {'label': 'LABEL_1', 'score': 0.4591068625450134},
#  {'label': 'LABEL_1', 'score': 0.6448612809181213},
#  {'label': 'LABEL_0', 'score': 0.9960582256317139},
#  {'label': 'LABEL_0', 'score': 0.8208625912666321},
#  {'label': 'LABEL_0', 'score': 0.9803531169891357},
#  {'label': 'LABEL_2', 'score': 0.8320514559745789},
#  {'label': 'LABEL_2', 'score': 0.6656044721603394},
#  {'label': 'LABEL_0', 'score': 0.8664128184318542},
#  {'label': 'LABEL_0', 'score': 0.5795453786849976},
#  {'label': 'LABEL_0', 'score': 0.992760419845581},
#  {'label': 'LABEL_2', 'score': 0.48121631145477295},
#  {'label': 'LABEL_0', 'score': 0.9956929087638855},
#  {'label': 'LABEL_0', 'score': 0.9962807297706604},
#  {'label': 'LABEL_0', 'score': 0.9948137998580933},
#  {'label': 'LABEL_0', 'score': 0.9928109049797058},
#  {'label': 'LABEL_0', 'score': 0.9960559606552124},
#  {'label': 'LABEL_0', 'score': 0.6125121116638184},
#  {'label': 'LABEL_0', 'score': 0.996080219745636},
#  {'label': 'LABEL_0', 'score': 0.9948450326919556},
#  {'label': 'LABEL_1', 'score': 0.9121989607810974},
#  {'label': 'LABEL_0', 'score': 0.9960033297538757},
#  {'label': 'LABEL_1', 'score': 0.44872400164604187},
#  {'label': 'LABEL_0', 'score': 0.8689610958099365},
#  {'label': 'LABEL_0', 'score': 0.9847036600112915},
#  {'label': 'LABEL_2', 'score': 0.9340588450431824},
#  {'label': 'LABEL_0', 'score': 0.9953625202178955},
#  {'label': 'LABEL_0', 'score': 0.9768203496932983},
#  {'label': 'LABEL_0', 'score': 0.9813263416290283},
#  {'label': 'LABEL_2', 'score': 0.5438445210456848},
#  {'label': 'LABEL_1', 'score': 0.7809334993362427},
#  {'label': 'LABEL_2', 'score': 0.6679513454437256},
#  {'label': 'LABEL_0', 'score': 0.9851893782615662},
#  {'label': 'LABEL_1', 'score': 0.8789623379707336},
#  {'label': 'LABEL_0', 'score': 0.9938294291496277},
#  {'label': 'LABEL_0', 'score': 0.9963893890380859},
#  {'label': 'LABEL_0', 'score': 0.9830799102783203},
#  {'label': 'LABEL_0', 'score': 0.8126226663589478},
#  {'label': 'LABEL_0', 'score': 0.9346568584442139},
#  {'label': 'LABEL_0', 'score': 0.9960290193557739},
#  {'label': 'LABEL_0', 'score': 0.9936699271202087},
#  {'label': 'LABEL_0', 'score': 0.9957072138786316},
#  {'label': 'LABEL_0', 'score': 0.7664945721626282},
#  {'label': 'LABEL_2', 'score': 0.9764072895050049},
#  {'label': 'LABEL_0', 'score': 0.9940588474273682},
#  {'label': 'LABEL_1', 'score': 0.7659533619880676},
#  {'label': 'LABEL_0', 'score': 0.9912176132202148},
#  {'label': 'LABEL_0', 'score': 0.9920480847358704},
#  {'label': 'LABEL_0', 'score': 0.9947503209114075},
#  {'label': 'LABEL_0', 'score': 0.9897441267967224},
#  {'label': 'LABEL_0', 'score': 0.8110878467559814},
#  {'label': 'LABEL_2', 'score': 0.9817221760749817},
#  {'label': 'LABEL_0', 'score': 0.990687906742096},
#  {'label': 'LABEL_0', 'score': 0.995965838432312},
#  {'label': 'LABEL_0', 'score': 0.9959022402763367},
#  {'label': 'LABEL_0', 'score': 0.9559360146522522},
#  {'label': 'LABEL_0', 'score': 0.9715378880500793},
#  {'label': 'LABEL_0', 'score': 0.927670419216156},
#  {'label': 'LABEL_0', 'score': 0.8074511289596558},
#  {'label': 'LABEL_0', 'score': 0.9190338253974915},
#  {'label': 'LABEL_2', 'score': 0.7958075404167175},
#  {'label': 'LABEL_0', 'score': 0.9036303162574768},
#  {'label': 'LABEL_0', 'score': 0.9940730929374695},
#  {'label': 'LABEL_0', 'score': 0.9731701612472534},
#  {'label': 'LABEL_0', 'score': 0.9952483773231506},
#  {'label': 'LABEL_0', 'score': 0.6466919779777527},
#  {'label': 'LABEL_0', 'score': 0.9965309500694275},
#  {'label': 'LABEL_1', 'score': 0.5168642997741699},
#  {'label': 'LABEL_1', 'score': 0.8716459274291992},
#  {'label': 'LABEL_0', 'score': 0.675897479057312},
#  {'label': 'LABEL_1', 'score': 0.9392004609107971},
#  {'label': 'LABEL_2', 'score': 0.9751302599906921},
#  {'label': 'LABEL_0', 'score': 0.9952881336212158},
#  {'label': 'LABEL_0', 'score': 0.9627328515052795},
#  {'label': 'LABEL_0', 'score': 0.976391613483429},
#  {'label': 'LABEL_2', 'score': 0.8064607381820679},
#  {'label': 'LABEL_0', 'score': 0.9148251414299011},
#  {'label': 'LABEL_0', 'score': 0.8725778460502625},
#  {'label': 'LABEL_0', 'score': 0.9929565191268921},
#  {'label': 'LABEL_0', 'score': 0.7082042098045349},
#  {'label': 'LABEL_0', 'score': 0.9276267886161804},
#  {'label': 'LABEL_0', 'score': 0.9903036952018738},
#  {'label': 'LABEL_0', 'score': 0.995471715927124},
#  {'label': 'LABEL_0', 'score': 0.9964587092399597},
#  {'label': 'LABEL_0', 'score': 0.9040827751159668},
#  {'label': 'LABEL_0', 'score': 0.9697473049163818},
#  {'label': 'LABEL_0', 'score': 0.995826780796051},
#  {'label': 'LABEL_2', 'score': 0.9780543446540833},
#  {'label': 'LABEL_2', 'score': 0.947358250617981},
#  {'label': 'LABEL_2', 'score': 0.9395737051963806},
#  {'label': 'LABEL_2', 'score': 0.9210988879203796},
#  {'label': 'LABEL_0', 'score': 0.9953041076660156},
#  {'label': 'LABEL_0', 'score': 0.8507644534111023},
#  {'label': 'LABEL_0', 'score': 0.9934957027435303},
#  {'label': 'LABEL_0', 'score': 0.9384246468544006},
#  {'label': 'LABEL_0', 'score': 0.9961269497871399},
#  {'label': 'LABEL_0', 'score': 0.9914114475250244},
#  {'label': 'LABEL_0', 'score': 0.9935619831085205},
#  {'label': 'LABEL_0', 'score': 0.9792262315750122},
#  {'label': 'LABEL_2', 'score': 0.6131983995437622},
#  {'label': 'LABEL_0', 'score': 0.9626438021659851},
#  {'label': 'LABEL_2', 'score': 0.9461473822593689},
#  {'label': 'LABEL_0', 'score': 0.9639111161231995},
#  {'label': 'LABEL_2', 'score': 0.6448484659194946},
#  {'label': 'LABEL_0', 'score': 0.9944555163383484},
#  {'label': 'LABEL_2', 'score': 0.956079363822937},
#  {'label': 'LABEL_2', 'score': 0.9649990200996399},
#  {'label': 'LABEL_2', 'score': 0.8760508894920349},
#  {'label': 'LABEL_2', 'score': 0.9428171515464783},
#  {'label': 'LABEL_2', 'score': 0.9515821933746338},
#  {'label': 'LABEL_0', 'score': 0.9680879712104797},
#  {'label': 'LABEL_0', 'score': 0.9969780445098877},
#  {'label': 'LABEL_0', 'score': 0.9795572757720947},
#  {'label': 'LABEL_0', 'score': 0.9962525367736816},
#  {'label': 'LABEL_2', 'score': 0.6651812791824341},
#  {'label': 'LABEL_0', 'score': 0.9942848086357117},
#  {'label': 'LABEL_1', 'score': 0.8506185412406921},
#  {'label': 'LABEL_0', 'score': 0.9961681962013245},
#  {'label': 'LABEL_0', 'score': 0.946487307548523},
#  {'label': 'LABEL_1', 'score': 0.9715496301651001},
#  {'label': 'LABEL_2', 'score': 0.9699004888534546},
#  {'label': 'LABEL_0', 'score': 0.9724822044372559},
#  {'label': 'LABEL_0', 'score': 0.994818389415741},
#  {'label': 'LABEL_0', 'score': 0.9858522415161133},
#  {'label': 'LABEL_0', 'score': 0.9924094676971436},
#  {'label': 'LABEL_0', 'score': 0.9959909319877625},
#  {'label': 'LABEL_0', 'score': 0.9625712037086487},
#  {'label': 'LABEL_0', 'score': 0.9901043772697449},
#  {'label': 'LABEL_0', 'score': 0.991647481918335},
#  {'label': 'LABEL_0', 'score': 0.9924975037574768},
#  {'label': 'LABEL_2', 'score': 0.9272124767303467},
#  {'label': 'LABEL_2', 'score': 0.94573575258255},
#  {'label': 'LABEL_2', 'score': 0.9792222380638123},
#  {'label': 'LABEL_0', 'score': 0.9956048727035522},
#  {'label': 'LABEL_0', 'score': 0.9898008704185486},
#  {'label': 'LABEL_0', 'score': 0.9959976673126221},
#  {'label': 'LABEL_0', 'score': 0.9945607781410217},
#  {'label': 'LABEL_2', 'score': 0.7944478392601013},
#  {'label': 'LABEL_2', 'score': 0.9860623478889465},
#  {'label': 'LABEL_2', 'score': 0.9457007646560669},
#  {'label': 'LABEL_1', 'score': 0.8809760212898254},
#  {'label': 'LABEL_2', 'score': 0.7092387080192566},
#  {'label': 'LABEL_0', 'score': 0.9900004863739014},
#  {'label': 'LABEL_0', 'score': 0.9777968525886536},
#  {'label': 'LABEL_0', 'score': 0.9958781003952026},
#  {'label': 'LABEL_0', 'score': 0.9912682771682739},
#  {'label': 'LABEL_2', 'score': 0.9456884264945984},
#  {'label': 'LABEL_0', 'score': 0.9964519739151001},
#  {'label': 'LABEL_1', 'score': 0.4708542823791504},
#  {'label': 'LABEL_0', 'score': 0.9948058724403381},
#  {'label': 'LABEL_2', 'score': 0.574215292930603},
#  {'label': 'LABEL_0', 'score': 0.7821860313415527},
#  {'label': 'LABEL_0', 'score': 0.9953676462173462},
#  {'label': 'LABEL_0', 'score': 0.9896706938743591},
#  {'label': 'LABEL_2', 'score': 0.9709933996200562},
#  {'label': 'LABEL_2', 'score': 0.9813066720962524},
#  {'label': 'LABEL_0', 'score': 0.9966850876808167},
#  {'label': 'LABEL_0', 'score': 0.9645954370498657},
#  {'label': 'LABEL_0', 'score': 0.7054575681686401},
#  {'label': 'LABEL_2', 'score': 0.8234702944755554},
#  {'label': 'LABEL_1', 'score': 0.7166114449501038},
#  {'label': 'LABEL_1', 'score': 0.8039788603782654},
#  {'label': 'LABEL_0', 'score': 0.8579717874526978},
#  {'label': 'LABEL_0', 'score': 0.9963429570198059},
#  {'label': 'LABEL_0', 'score': 0.9912621974945068},
#  {'label': 'LABEL_0', 'score': 0.975102961063385},
#  {'label': 'LABEL_0', 'score': 0.9376679062843323},
#  {'label': 'LABEL_1', 'score': 0.6679672598838806},
#  {'label': 'LABEL_0', 'score': 0.9964272379875183},
#  {'label': 'LABEL_0', 'score': 0.9958003163337708},
#  {'label': 'LABEL_0', 'score': 0.995826005935669},
#  {'label': 'LABEL_2', 'score': 0.851245641708374},
#  {'label': 'LABEL_2', 'score': 0.9520420432090759},
#  {'label': 'LABEL_0', 'score': 0.9958665370941162},
#  {'label': 'LABEL_1', 'score': 0.9772174954414368},
#  {'label': 'LABEL_0', 'score': 0.4995400309562683},
#  {'label': 'LABEL_0', 'score': 0.7671512365341187},
#  {'label': 'LABEL_0', 'score': 0.9915475249290466},
#  {'label': 'LABEL_0', 'score': 0.9712724089622498},
#  {'label': 'LABEL_0', 'score': 0.8480067849159241},
#  {'label': 'LABEL_0', 'score': 0.9427055716514587},
#  {'label': 'LABEL_2', 'score': 0.9655932784080505},
#  {'label': 'LABEL_1', 'score': 0.9201691746711731},
#  {'label': 'LABEL_2', 'score': 0.7000089287757874},
#  {'label': 'LABEL_0', 'score': 0.9954308271408081},
#  {'label': 'LABEL_0', 'score': 0.9724466800689697},
#  {'label': 'LABEL_2', 'score': 0.6924458742141724},
#  {'label': 'LABEL_2', 'score': 0.8042872548103333},
#  {'label': 'LABEL_2', 'score': 0.9046348929405212},
#  {'label': 'LABEL_0', 'score': 0.9945684671401978},
#  {'label': 'LABEL_0', 'score': 0.983895480632782},
#  {'label': 'LABEL_1', 'score': 0.9321234822273254},
#  {'label': 'LABEL_2', 'score': 0.979649543762207},
#  {'label': 'LABEL_0', 'score': 0.9959495067596436},
#  {'label': 'LABEL_0', 'score': 0.9954105019569397},
#  {'label': 'LABEL_0', 'score': 0.8513429164886475},
#  {'label': 'LABEL_0', 'score': 0.4903935194015503},
#  {'label': 'LABEL_2', 'score': 0.9430907368659973},
#  {'label': 'LABEL_1', 'score': 0.9298374056816101},
#  {'label': 'LABEL_2', 'score': 0.9260715246200562},
#  {'label': 'LABEL_0', 'score': 0.9890055060386658},
#  {'label': 'LABEL_2', 'score': 0.9867505431175232},
#  {'label': 'LABEL_2', 'score': 0.9846699237823486},
#  {'label': 'LABEL_0', 'score': 0.9940356016159058},
#  {'label': 'LABEL_2', 'score': 0.9773197174072266},
#  {'label': 'LABEL_2', 'score': 0.5027998089790344},
#  {'label': 'LABEL_0', 'score': 0.8898404836654663},
#  {'label': 'LABEL_0', 'score': 0.9954547882080078},
#  {'label': 'LABEL_0', 'score': 0.9892925024032593},
#  {'label': 'LABEL_2', 'score': 0.9358822107315063},
#  {'label': 'LABEL_1', 'score': 0.8336466550827026},
#  {'label': 'LABEL_0', 'score': 0.9296122193336487},
#  {'label': 'LABEL_2', 'score': 0.888186514377594},
#  {'label': 'LABEL_0', 'score': 0.9802708625793457},
#  {'label': 'LABEL_0', 'score': 0.9803065061569214},
#  {'label': 'LABEL_0', 'score': 0.9490780830383301},
#  {'label': 'LABEL_2', 'score': 0.6662579774856567},
#  {'label': 'LABEL_0', 'score': 0.9322554469108582},
#  {'label': 'LABEL_0', 'score': 0.9833784103393555},
#  {'label': 'LABEL_0', 'score': 0.9886550903320312},
#  {'label': 'LABEL_0', 'score': 0.9890840649604797},
#  {'label': 'LABEL_1', 'score': 0.868325412273407},
#  {'label': 'LABEL_0', 'score': 0.791002631187439},
#  {'label': 'LABEL_0', 'score': 0.9432011842727661},
#  {'label': 'LABEL_0', 'score': 0.9964858293533325},
#  {'label': 'LABEL_0', 'score': 0.9543466567993164},
#  {'label': 'LABEL_0', 'score': 0.9842618703842163},
#  {'label': 'LABEL_2', 'score': 0.779399037361145},
#  {'label': 'LABEL_0', 'score': 0.5254364609718323},
#  {'label': 'LABEL_0', 'score': 0.5709830522537231},
#  {'label': 'LABEL_0', 'score': 0.9956756234169006},
#  {'label': 'LABEL_0', 'score': 0.9897462129592896},
#  {'label': 'LABEL_0', 'score': 0.9584435224533081},
#  {'label': 'LABEL_2', 'score': 0.6453765034675598},
#  {'label': 'LABEL_0', 'score': 0.9485371112823486},
#  {'label': 'LABEL_2', 'score': 0.968313455581665},
#  {'label': 'LABEL_0', 'score': 0.9956660270690918},
#  {'label': 'LABEL_0', 'score': 0.9737840294837952},
#  {'label': 'LABEL_0', 'score': 0.9951062202453613},
#  {'label': 'LABEL_0', 'score': 0.9932324886322021},
#  {'label': 'LABEL_0', 'score': 0.9928818941116333},
#  {'label': 'LABEL_0', 'score': 0.7979790568351746},
#  {'label': 'LABEL_0', 'score': 0.872108519077301},
#  {'label': 'LABEL_0', 'score': 0.9956451654434204},
#  {'label': 'LABEL_0', 'score': 0.9682812690734863},
#  {'label': 'LABEL_0', 'score': 0.648330569267273},
#  {'label': 'LABEL_1', 'score': 0.951093852519989},
#  {'label': 'LABEL_0', 'score': 0.9817505478858948},
#  {'label': 'LABEL_0', 'score': 0.9935871362686157},
#  {'label': 'LABEL_1', 'score': 0.9800981283187866},
#  {'label': 'LABEL_2', 'score': 0.8130804300308228},
#  {'label': 'LABEL_0', 'score': 0.8258042335510254},
#  {'label': 'LABEL_0', 'score': 0.9911511540412903},
#  {'label': 'LABEL_0', 'score': 0.6429455280303955},
#  {'label': 'LABEL_1', 'score': 0.6245658993721008},
#  {'label': 'LABEL_1', 'score': 0.9556944370269775},
#  {'label': 'LABEL_0', 'score': 0.9953822493553162},
#  {'label': 'LABEL_0', 'score': 0.88950115442276},
#  {'label': 'LABEL_2', 'score': 0.4892343580722809},
#  {'label': 'LABEL_0', 'score': 0.8541460633277893},
#  {'label': 'LABEL_0', 'score': 0.8191725611686707},
#  {'label': 'LABEL_0', 'score': 0.7496821284294128},
#  {'label': 'LABEL_0', 'score': 0.9966009855270386},
#  {'label': 'LABEL_2', 'score': 0.8944537043571472},
#  {'label': 'LABEL_2', 'score': 0.9779470562934875},
#  {'label': 'LABEL_0', 'score': 0.8984378576278687},
#  {'label': 'LABEL_0', 'score': 0.9948371648788452},
#  {'label': 'LABEL_0', 'score': 0.9913930892944336},
#  {'label': 'LABEL_2', 'score': 0.9408661127090454},
#  {'label': 'LABEL_0', 'score': 0.9919856786727905},
#  {'label': 'LABEL_1', 'score': 0.9575700759887695},
#  {'label': 'LABEL_2', 'score': 0.8958965539932251},
#  {'label': 'LABEL_0', 'score': 0.966981053352356},
#  {'label': 'LABEL_0', 'score': 0.9947642087936401},
#  {'label': 'LABEL_0', 'score': 0.9923884272575378},
#  {'label': 'LABEL_0', 'score': 0.9959644079208374},
#  {'label': 'LABEL_0', 'score': 0.8484408259391785},
#  {'label': 'LABEL_0', 'score': 0.9943939447402954},
#  {'label': 'LABEL_2', 'score': 0.9284022450447083},
#  {'label': 'LABEL_2', 'score': 0.8302772045135498},
#  {'label': 'LABEL_0', 'score': 0.8996937870979309},
#  {'label': 'LABEL_0', 'score': 0.9721921682357788},
#  {'label': 'LABEL_2', 'score': 0.9357420206069946},
#  {'label': 'LABEL_2', 'score': 0.9792782068252563},
#  {'label': 'LABEL_0', 'score': 0.9962469935417175},
#  {'label': 'LABEL_0', 'score': 0.7814337015151978},
#  {'label': 'LABEL_0', 'score': 0.9922188520431519},
#  {'label': 'LABEL_2', 'score': 0.9830992817878723},
#  {'label': 'LABEL_2', 'score': 0.8239942193031311},
#  {'label': 'LABEL_0', 'score': 0.9920578598976135},
#  {'label': 'LABEL_2', 'score': 0.9125243425369263},
#  {'label': 'LABEL_0', 'score': 0.892184317111969},
#  {'label': 'LABEL_1', 'score': 0.9320304989814758},
#  {'label': 'LABEL_2', 'score': 0.9736372232437134},
#  {'label': 'LABEL_2', 'score': 0.9435292482376099},
#  {'label': 'LABEL_0', 'score': 0.9931278228759766},
#  {'label': 'LABEL_0', 'score': 0.981845498085022},
#  {'label': 'LABEL_0', 'score': 0.9764072895050049},
#  {'label': 'LABEL_0', 'score': 0.9959261417388916},
#  {'label': 'LABEL_2', 'score': 0.8742529153823853},
#  {'label': 'LABEL_0', 'score': 0.9598891139030457},
#  {'label': 'LABEL_1', 'score': 0.8406444787979126},
#  {'label': 'LABEL_2', 'score': 0.8862480521202087},
#  {'label': 'LABEL_0', 'score': 0.5658116936683655},
#  {'label': 'LABEL_0', 'score': 0.8127560615539551},
#  {'label': 'LABEL_0', 'score': 0.9907500147819519},
#  {'label': 'LABEL_0', 'score': 0.9938653111457825},
#  {'label': 'LABEL_0', 'score': 0.9223799109458923},
#  {'label': 'LABEL_0', 'score': 0.8506996631622314},
#  {'label': 'LABEL_0', 'score': 0.9196745157241821},
#  {'label': 'LABEL_0', 'score': 0.9883290529251099},
#  {'label': 'LABEL_0', 'score': 0.8012818098068237},
#  {'label': 'LABEL_1', 'score': 0.6319775581359863},
#  {'label': 'LABEL_0', 'score': 0.9320511817932129},
#  {'label': 'LABEL_0', 'score': 0.5850125551223755},
#  {'label': 'LABEL_0', 'score': 0.9328690767288208},
#  {'label': 'LABEL_2', 'score': 0.9787871241569519},
#  {'label': 'LABEL_0', 'score': 0.9957605004310608},
#  {'label': 'LABEL_0', 'score': 0.9666928648948669},
#  {'label': 'LABEL_2', 'score': 0.5024963617324829},
#  {'label': 'LABEL_0', 'score': 0.990445613861084},
#  {'label': 'LABEL_0', 'score': 0.992926299571991},
#  {'label': 'LABEL_2', 'score': 0.5648056268692017},
#  {'label': 'LABEL_0', 'score': 0.9876091480255127},
#  {'label': 'LABEL_2', 'score': 0.9065641164779663},
#  {'label': 'LABEL_1', 'score': 0.7572557926177979},
#  {'label': 'LABEL_2', 'score': 0.6500950455665588},
#  {'label': 'LABEL_0', 'score': 0.9906490445137024},
#  {'label': 'LABEL_0', 'score': 0.9948545694351196},
#  {'label': 'LABEL_0', 'score': 0.9814600944519043},
#  {'label': 'LABEL_0', 'score': 0.9303683042526245},
#  {'label': 'LABEL_2', 'score': 0.7732389569282532},
#  {'label': 'LABEL_0', 'score': 0.8082588315010071},
#  {'label': 'LABEL_0', 'score': 0.6297920346260071},
#  {'label': 'LABEL_0', 'score': 0.9917044639587402},
#  {'label': 'LABEL_1', 'score': 0.9718121886253357},
#  {'label': 'LABEL_2', 'score': 0.9024728536605835},
#  {'label': 'LABEL_1', 'score': 0.9075705409049988},
#  {'label': 'LABEL_1', 'score': 0.9169580936431885},
#  {'label': 'LABEL_0', 'score': 0.9948019981384277},
#  {'label': 'LABEL_2', 'score': 0.9801024794578552},
#  {'label': 'LABEL_2', 'score': 0.7188501358032227},
#  {'label': 'LABEL_0', 'score': 0.8413798809051514},
#  {'label': 'LABEL_1', 'score': 0.8628115057945251},
#  {'label': 'LABEL_2', 'score': 0.6721523404121399},
#  {'label': 'LABEL_0', 'score': 0.9902082681655884},
#  {'label': 'LABEL_0', 'score': 0.8571875691413879},
#  {'label': 'LABEL_0', 'score': 0.987286388874054},
#  {'label': 'LABEL_0', 'score': 0.9892039895057678},
#  {'label': 'LABEL_0', 'score': 0.5970799326896667},
#  {'label': 'LABEL_2', 'score': 0.9230169653892517},
#  {'label': 'LABEL_0', 'score': 0.9956390857696533},
#  {'label': 'LABEL_0', 'score': 0.9951594471931458},
#  {'label': 'LABEL_1', 'score': 0.9537385106086731},
#  {'label': 'LABEL_0', 'score': 0.959153413772583},
#  {'label': 'LABEL_0', 'score': 0.826004147529602},
#  {'label': 'LABEL_2', 'score': 0.9049091339111328},
#  {'label': 'LABEL_0', 'score': 0.994938850402832},
#  {'label': 'LABEL_1', 'score': 0.9268721342086792},
#  {'label': 'LABEL_0', 'score': 0.9946670532226562},
#  {'label': 'LABEL_1', 'score': 0.7897343635559082},
#  {'label': 'LABEL_0', 'score': 0.9927375912666321},
#  {'label': 'LABEL_2', 'score': 0.9748656749725342},
#  {'label': 'LABEL_0', 'score': 0.6653336882591248},
#  {'label': 'LABEL_1', 'score': 0.9695862531661987},
#  {'label': 'LABEL_2', 'score': 0.9745025038719177},
#  {'label': 'LABEL_0', 'score': 0.9944918155670166},
#  {'label': 'LABEL_0', 'score': 0.9906288981437683},
#  {'label': 'LABEL_1', 'score': 0.6157146096229553},
#  {'label': 'LABEL_0', 'score': 0.9478542804718018},
#  {'label': 'LABEL_1', 'score': 0.973339855670929},
#  {'label': 'LABEL_0', 'score': 0.854896605014801},
#  {'label': 'LABEL_0', 'score': 0.9961833357810974},
#  {'label': 'LABEL_1', 'score': 0.6823873519897461},
#  {'label': 'LABEL_1', 'score': 0.9516966938972473},
#  {'label': 'LABEL_0', 'score': 0.8893210291862488},
#  {'label': 'LABEL_0', 'score': 0.9958894848823547},
#  {'label': 'LABEL_0', 'score': 0.9964697360992432},
#  {'label': 'LABEL_0', 'score': 0.9768381118774414},
#  {'label': 'LABEL_0', 'score': 0.9640719890594482},
#  {'label': 'LABEL_1', 'score': 0.933363139629364},
#  {'label': 'LABEL_0', 'score': 0.9233503341674805},
#  {'label': 'LABEL_0', 'score': 0.9927904605865479},
#  {'label': 'LABEL_2', 'score': 0.5752004981040955},
#  {'label': 'LABEL_0', 'score': 0.9948055148124695},
#  {'label': 'LABEL_2', 'score': 0.5862529277801514},
#  {'label': 'LABEL_1', 'score': 0.613179087638855},
#  {'label': 'LABEL_1', 'score': 0.6210249066352844},
#  {'label': 'LABEL_0', 'score': 0.9803840517997742},
#  {'label': 'LABEL_0', 'score': 0.884545624256134},
#  {'label': 'LABEL_0', 'score': 0.9893249869346619},
#  {'label': 'LABEL_0', 'score': 0.9940444827079773},
#  {'label': 'LABEL_1', 'score': 0.737788736820221},
#  {'label': 'LABEL_0', 'score': 0.9485581517219543},
#  {'label': 'LABEL_2', 'score': 0.9789496660232544},
#  {'label': 'LABEL_0', 'score': 0.9956299066543579},
#  {'label': 'LABEL_0', 'score': 0.9892190098762512},
#  {'label': 'LABEL_2', 'score': 0.7555223107337952},
#  {'label': 'LABEL_0', 'score': 0.9726411700248718},
#  {'label': 'LABEL_0', 'score': 0.8587108254432678},
#  {'label': 'LABEL_0', 'score': 0.7331768274307251},
#  {'label': 'LABEL_1', 'score': 0.7325699925422668},
#  {'label': 'LABEL_2', 'score': 0.969723641872406},
#  {'label': 'LABEL_2', 'score': 0.9118374586105347},
#  {'label': 'LABEL_2', 'score': 0.9561643600463867},
#  {'label': 'LABEL_0', 'score': 0.9890127182006836},
#  {'label': 'LABEL_2', 'score': 0.9814295172691345},
#  {'label': 'LABEL_2', 'score': 0.9087079763412476},
#  {'label': 'LABEL_0', 'score': 0.9717066884040833},
#  {'label': 'LABEL_1', 'score': 0.9205806255340576},
#  {'label': 'LABEL_0', 'score': 0.989641010761261},
#  {'label': 'LABEL_0', 'score': 0.8440743088722229},
#  {'label': 'LABEL_0', 'score': 0.4932307302951813},
#  {'label': 'LABEL_0', 'score': 0.6625633835792542},
#  {'label': 'LABEL_0', 'score': 0.9954540729522705},
#  {'label': 'LABEL_0', 'score': 0.9306808114051819},
#  {'label': 'LABEL_2', 'score': 0.8233617544174194},
#  {'label': 'LABEL_0', 'score': 0.9695409536361694},
#  {'label': 'LABEL_1', 'score': 0.7397996783256531},
#  {'label': 'LABEL_0', 'score': 0.8358206152915955},
#  {'label': 'LABEL_2', 'score': 0.9118953347206116},
#  {'label': 'LABEL_2', 'score': 0.5114170908927917},
#  {'label': 'LABEL_1', 'score': 0.435397744178772},
#  {'label': 'LABEL_0', 'score': 0.9950119256973267},
#  {'label': 'LABEL_2', 'score': 0.46559861302375793},
#  {'label': 'LABEL_0', 'score': 0.9913538098335266},
#  {'label': 'LABEL_0', 'score': 0.9966212511062622},
#  {'label': 'LABEL_1', 'score': 0.8825234770774841},
#  {'label': 'LABEL_0', 'score': 0.9925737380981445},
#  {'label': 'LABEL_0', 'score': 0.9906023740768433},
#  {'label': 'LABEL_0', 'score': 0.9907734394073486},
#  {'label': 'LABEL_2', 'score': 0.6498966217041016},
#  {'label': 'LABEL_0', 'score': 0.8463740348815918},
#  {'label': 'LABEL_0', 'score': 0.9954040050506592},
#  {'label': 'LABEL_2', 'score': 0.8771061301231384},
#  {'label': 'LABEL_0', 'score': 0.9957265853881836},
#  {'label': 'LABEL_0', 'score': 0.995062530040741},
#  {'label': 'LABEL_2', 'score': 0.6332822442054749},
#  {'label': 'LABEL_2', 'score': 0.9783093929290771},
#  {'label': 'LABEL_0', 'score': 0.9642537832260132},
#  {'label': 'LABEL_0', 'score': 0.9751551151275635},
#  {'label': 'LABEL_2', 'score': 0.8240175843238831},
#  {'label': 'LABEL_0', 'score': 0.9910405278205872},
#  {'label': 'LABEL_1', 'score': 0.971045970916748},
#  {'label': 'LABEL_0', 'score': 0.9727535247802734},
#  {'label': 'LABEL_2', 'score': 0.5217713117599487},
#  {'label': 'LABEL_0', 'score': 0.9929793477058411},
#  {'label': 'LABEL_0', 'score': 0.9845905303955078},
#  {'label': 'LABEL_0', 'score': 0.8778932690620422},
#  {'label': 'LABEL_0', 'score': 0.9958716034889221},
#  {'label': 'LABEL_0', 'score': 0.5575114488601685},
#  {'label': 'LABEL_2', 'score': 0.9617522358894348},
#  {'label': 'LABEL_1', 'score': 0.9537747502326965},
#  {'label': 'LABEL_0', 'score': 0.9959781169891357},
#  {'label': 'LABEL_1', 'score': 0.9699780941009521},
#  {'label': 'LABEL_2', 'score': 0.8145022392272949},
#  {'label': 'LABEL_2', 'score': 0.9733049869537354},
#  {'label': 'LABEL_2', 'score': 0.6499024033546448},
#  {'label': 'LABEL_0', 'score': 0.9965406060218811},
#  {'label': 'LABEL_0', 'score': 0.9862903952598572},
#  {'label': 'LABEL_2', 'score': 0.9663201570510864},
#  {'label': 'LABEL_0', 'score': 0.9856686592102051},
#  {'label': 'LABEL_0', 'score': 0.743076503276825},
#  {'label': 'LABEL_0', 'score': 0.9643508195877075},
#  {'label': 'LABEL_1', 'score': 0.8733134269714355},
#  {'label': 'LABEL_2', 'score': 0.8566824793815613},
#  {'label': 'LABEL_2', 'score': 0.7798097133636475},
#  {'label': 'LABEL_0', 'score': 0.9899230599403381},
#  {'label': 'LABEL_0', 'score': 0.9932560920715332},
#  {'label': 'LABEL_0', 'score': 0.8042762279510498},
#  {'label': 'LABEL_0', 'score': 0.9962717294692993},
#  {'label': 'LABEL_2', 'score': 0.9591696262359619},
#  {'label': 'LABEL_2', 'score': 0.9376980066299438},
#  {'label': 'LABEL_2', 'score': 0.9719518423080444},
#  {'label': 'LABEL_0', 'score': 0.9895078539848328},
#  {'label': 'LABEL_0', 'score': 0.9959872364997864},
#  {'label': 'LABEL_0', 'score': 0.9483886957168579},
#  {'label': 'LABEL_2', 'score': 0.584854781627655},
#  {'label': 'LABEL_2', 'score': 0.9684868454933167},
#  {'label': 'LABEL_0', 'score': 0.9955236911773682},
#  {'label': 'LABEL_0', 'score': 0.9925016164779663},
#  {'label': 'LABEL_2', 'score': 0.9372494220733643},
#  {'label': 'LABEL_2', 'score': 0.9727115631103516},
#  {'label': 'LABEL_0', 'score': 0.9891604781150818},
#  {'label': 'LABEL_0', 'score': 0.7676097750663757},
#  {'label': 'LABEL_1', 'score': 0.7556460499763489},
#  {'label': 'LABEL_1', 'score': 0.8443379998207092},
#  {'label': 'LABEL_0', 'score': 0.9748879671096802},
#  {'label': 'LABEL_0', 'score': 0.9954482913017273},
#  {'label': 'LABEL_0', 'score': 0.7414016127586365},
#  {'label': 'LABEL_0', 'score': 0.989750325679779},
#  {'label': 'LABEL_1', 'score': 0.9566766619682312},
#  {'label': 'LABEL_0', 'score': 0.9036849141120911},
#  {'label': 'LABEL_0', 'score': 0.9734414219856262},
#  {'label': 'LABEL_0', 'score': 0.9916198253631592},
#  {'label': 'LABEL_0', 'score': 0.9282994866371155},
#  {'label': 'LABEL_0', 'score': 0.9891902208328247},
#  {'label': 'LABEL_0', 'score': 0.988075852394104},
#  {'label': 'LABEL_0', 'score': 0.9758934378623962},
#  {'label': 'LABEL_2', 'score': 0.9811010360717773},
#  {'label': 'LABEL_0', 'score': 0.9853808283805847},
#  {'label': 'LABEL_0', 'score': 0.9857864379882812},
#  {'label': 'LABEL_0', 'score': 0.9673026204109192},
#  {'label': 'LABEL_0', 'score': 0.9944061040878296},
#  {'label': 'LABEL_2', 'score': 0.950933039188385},
#  {'label': 'LABEL_0', 'score': 0.9955783486366272},
#  {'label': 'LABEL_0', 'score': 0.9578927755355835},
#  {'label': 'LABEL_0', 'score': 0.9963904023170471},
#  {'label': 'LABEL_2', 'score': 0.9275160431861877},
#  {'label': 'LABEL_2', 'score': 0.9713448286056519},
#  {'label': 'LABEL_2', 'score': 0.9594920873641968},
#  {'label': 'LABEL_0', 'score': 0.9946050047874451},
#  {'label': 'LABEL_0', 'score': 0.9749916791915894},
#  {'label': 'LABEL_1', 'score': 0.9647809267044067},
#  {'label': 'LABEL_0', 'score': 0.9768722057342529},
#  {'label': 'LABEL_0', 'score': 0.9957593083381653},
#  {'label': 'LABEL_0', 'score': 0.9598115682601929},
#  {'label': 'LABEL_2', 'score': 0.9819059371948242},
#  {'label': 'LABEL_0', 'score': 0.9705365896224976},
#  {'label': 'LABEL_0', 'score': 0.9888991713523865},
#  {'label': 'LABEL_2', 'score': 0.8861055374145508},
#  {'label': 'LABEL_1', 'score': 0.703082263469696},
#  {'label': 'LABEL_2', 'score': 0.9562632441520691},
#  {'label': 'LABEL_0', 'score': 0.9351654648780823},
#  {'label': 'LABEL_0', 'score': 0.9488040208816528},
#  {'label': 'LABEL_0', 'score': 0.9607131481170654},
#  {'label': 'LABEL_1', 'score': 0.8504131436347961},
#  {'label': 'LABEL_0', 'score': 0.9952753782272339},
#  {'label': 'LABEL_2', 'score': 0.9566875100135803},
#  {'label': 'LABEL_0', 'score': 0.9965288043022156},
#  {'label': 'LABEL_2', 'score': 0.6702172756195068},
#  {'label': 'LABEL_1', 'score': 0.967252790927887},
#  {'label': 'LABEL_0', 'score': 0.9881211519241333},
#  {'label': 'LABEL_1', 'score': 0.9563590884208679},
#  {'label': 'LABEL_2', 'score': 0.9723735451698303},
#  {'label': 'LABEL_1', 'score': 0.9132583141326904},
#  {'label': 'LABEL_2', 'score': 0.8557782769203186},
#  {'label': 'LABEL_0', 'score': 0.993887722492218},
#  {'label': 'LABEL_0', 'score': 0.69677734375},
#  {'label': 'LABEL_2', 'score': 0.936166524887085},
#  {'label': 'LABEL_1', 'score': 0.8866545557975769},
#  {'label': 'LABEL_0', 'score': 0.8694651126861572},
#  {'label': 'LABEL_0', 'score': 0.9932867884635925},
#  {'label': 'LABEL_0', 'score': 0.9684988260269165},
#  {'label': 'LABEL_1', 'score': 0.9261848330497742},
#  {'label': 'LABEL_2', 'score': 0.9669585227966309},
#  {'label': 'LABEL_0', 'score': 0.9941699504852295},
#  {'label': 'LABEL_2', 'score': 0.9854595065116882},
#  {'label': 'LABEL_2', 'score': 0.5785179734230042},
#  {'label': 'LABEL_1', 'score': 0.7055301070213318},
#  {'label': 'LABEL_0', 'score': 0.8745720982551575},
#  {'label': 'LABEL_0', 'score': 0.9960417747497559},
#  {'label': 'LABEL_0', 'score': 0.9940872192382812},
#  {'label': 'LABEL_0', 'score': 0.9846953749656677},
#  {'label': 'LABEL_1', 'score': 0.8914704918861389},
#  {'label': 'LABEL_0', 'score': 0.9930422306060791},
#  {'label': 'LABEL_1', 'score': 0.7893330454826355},
#  {'label': 'LABEL_0', 'score': 0.9963078498840332},
#  {'label': 'LABEL_0', 'score': 0.9956814050674438},
#  {'label': 'LABEL_1', 'score': 0.9710162878036499},
#  {'label': 'LABEL_2', 'score': 0.8919899463653564},
#  {'label': 'LABEL_2', 'score': 0.9689703583717346},
#  {'label': 'LABEL_0', 'score': 0.9887606501579285},
#  {'label': 'LABEL_2', 'score': 0.8738112449645996},
#  {'label': 'LABEL_2', 'score': 0.9647044539451599},
#  {'label': 'LABEL_2', 'score': 0.9510799646377563},
#  {'label': 'LABEL_0', 'score': 0.9942973256111145},
#  {'label': 'LABEL_0', 'score': 0.9341142177581787},
#  {'label': 'LABEL_2', 'score': 0.8675808310508728},
#  {'label': 'LABEL_0', 'score': 0.9913663268089294},
#  {'label': 'LABEL_0', 'score': 0.9929934144020081},
#  {'label': 'LABEL_1', 'score': 0.6823866367340088},
#  {'label': 'LABEL_0', 'score': 0.9133251309394836},
#  {'label': 'LABEL_2', 'score': 0.64812833070755},
#  {'label': 'LABEL_0', 'score': 0.8080970048904419},
#  {'label': 'LABEL_1', 'score': 0.9192241430282593},
#  {'label': 'LABEL_0', 'score': 0.989844799041748},
#  {'label': 'LABEL_0', 'score': 0.9958329796791077},
#  {'label': 'LABEL_0', 'score': 0.9955458641052246},
#  {'label': 'LABEL_0', 'score': 0.9748900532722473},
#  {'label': 'LABEL_0', 'score': 0.9666405320167542},
#  {'label': 'LABEL_0', 'score': 0.9958641529083252},
#  {'label': 'LABEL_0', 'score': 0.9963931441307068},
#  {'label': 'LABEL_0', 'score': 0.9950833320617676},
#  {'label': 'LABEL_0', 'score': 0.9950858950614929},
#  {'label': 'LABEL_0', 'score': 0.9963510036468506},
#  {'label': 'LABEL_2', 'score': 0.9711548089981079},
#  {'label': 'LABEL_0', 'score': 0.9745420813560486},
#  {'label': 'LABEL_0', 'score': 0.983325719833374},
#  {'label': 'LABEL_2', 'score': 0.5868721008300781},
#  {'label': 'LABEL_2', 'score': 0.7387007474899292},
#  {'label': 'LABEL_2', 'score': 0.7170530557632446},
#  {'label': 'LABEL_0', 'score': 0.9645194411277771},
#  {'label': 'LABEL_1', 'score': 0.7973673343658447},
#  {'label': 'LABEL_0', 'score': 0.9722488522529602},
#  {'label': 'LABEL_0', 'score': 0.9964368343353271},
#  {'label': 'LABEL_2', 'score': 0.9044603109359741},
#  {'label': 'LABEL_0', 'score': 0.9816754460334778},
#  {'label': 'LABEL_2', 'score': 0.96541827917099},
#  {'label': 'LABEL_1', 'score': 0.9525827169418335},
#  {'label': 'LABEL_0', 'score': 0.8920274972915649},
#  {'label': 'LABEL_1', 'score': 0.8216540217399597},
#  {'label': 'LABEL_2', 'score': 0.5393186807632446},
#  {'label': 'LABEL_1', 'score': 0.8062855005264282},
#  {'label': 'LABEL_0', 'score': 0.9926958084106445},
#  {'label': 'LABEL_0', 'score': 0.9486773014068604},
#  {'label': 'LABEL_0', 'score': 0.9905727505683899},
#  {'label': 'LABEL_1', 'score': 0.8768822550773621},
#  {'label': 'LABEL_0', 'score': 0.9915193915367126},
#  {'label': 'LABEL_2', 'score': 0.8666635155677795},
#  {'label': 'LABEL_0', 'score': 0.9951305389404297},
#  {'label': 'LABEL_0', 'score': 0.9481502771377563},
#  {'label': 'LABEL_0', 'score': 0.9911370277404785},
#  {'label': 'LABEL_0', 'score': 0.9950987696647644},
#  {'label': 'LABEL_1', 'score': 0.9469472765922546},
#  {'label': 'LABEL_0', 'score': 0.9915391802787781},
#  {'label': 'LABEL_2', 'score': 0.4902150630950928},
#  {'label': 'LABEL_2', 'score': 0.966738760471344},
#  {'label': 'LABEL_0', 'score': 0.99472975730896},
#  {'label': 'LABEL_0', 'score': 0.9956448078155518},
#  {'label': 'LABEL_0', 'score': 0.9666135907173157},
#  {'label': 'LABEL_0', 'score': 0.9941083192825317},
#  {'label': 'LABEL_0', 'score': 0.9957097768783569},
#  {'label': 'LABEL_0', 'score': 0.9928512573242188},
#  {'label': 'LABEL_1', 'score': 0.9605538249015808},
#  {'label': 'LABEL_1', 'score': 0.8688601851463318},
#  {'label': 'LABEL_0', 'score': 0.9727171659469604},
#  {'label': 'LABEL_2', 'score': 0.8636135458946228},
#  {'label': 'LABEL_0', 'score': 0.9635319113731384},
#  {'label': 'LABEL_0', 'score': 0.9917430281639099},
#  {'label': 'LABEL_0', 'score': 0.9919589757919312},
#  {'label': 'LABEL_0', 'score': 0.9964063763618469},
#  {'label': 'LABEL_1', 'score': 0.9623651504516602},
#  {'label': 'LABEL_0', 'score': 0.6202424168586731},
#  {'label': 'LABEL_0', 'score': 0.9888339638710022},
#  {'label': 'LABEL_1', 'score': 0.9713891744613647},
#  {'label': 'LABEL_0', 'score': 0.8541857600212097},
#  {'label': 'LABEL_0', 'score': 0.9624239206314087},
#  {'label': 'LABEL_0', 'score': 0.9961484670639038},
#  {'label': 'LABEL_0', 'score': 0.7335253953933716},
#  {'label': 'LABEL_1', 'score': 0.9441460371017456},
#  {'label': 'LABEL_0', 'score': 0.9659891128540039},
#  {'label': 'LABEL_2', 'score': 0.9448294639587402},
#  {'label': 'LABEL_0', 'score': 0.993780791759491},
#  {'label': 'LABEL_0', 'score': 0.9915036559104919},
#  {'label': 'LABEL_1', 'score': 0.9601951837539673},
#  {'label': 'LABEL_1', 'score': 0.9270638823509216},
#  {'label': 'LABEL_0', 'score': 0.8809168934822083},
#  {'label': 'LABEL_0', 'score': 0.988157331943512},
#  {'label': 'LABEL_0', 'score': 0.9943053126335144},
#  {'label': 'LABEL_2', 'score': 0.9782828092575073},
#  {'label': 'LABEL_1', 'score': 0.877638578414917},
#  {'label': 'LABEL_2', 'score': 0.9472811818122864},
#  {'label': 'LABEL_0', 'score': 0.9936158657073975},
#  {'label': 'LABEL_2', 'score': 0.9584001302719116},
#  {'label': 'LABEL_2', 'score': 0.5585317015647888},
#  {'label': 'LABEL_2', 'score': 0.9437402486801147},
#  {'label': 'LABEL_0', 'score': 0.6374528408050537},
#  {'label': 'LABEL_0', 'score': 0.9870463609695435},
#  {'label': 'LABEL_0', 'score': 0.972175657749176},
#  {'label': 'LABEL_0', 'score': 0.9941313862800598},
#  {'label': 'LABEL_0', 'score': 0.9916810393333435},
#  {'label': 'LABEL_0', 'score': 0.9941664934158325},
#  {'label': 'LABEL_0', 'score': 0.5847681760787964},
#  {'label': 'LABEL_0', 'score': 0.9783737659454346},
#  {'label': 'LABEL_0', 'score': 0.9907351732254028},
#  {'label': 'LABEL_2', 'score': 0.7830944657325745},
#  {'label': 'LABEL_0', 'score': 0.9912896156311035},
#  {'label': 'LABEL_0', 'score': 0.9960649609565735},
#  {'label': 'LABEL_1', 'score': 0.8372011184692383},
#  {'label': 'LABEL_0', 'score': 0.9305721521377563},
#  {'label': 'LABEL_0', 'score': 0.9394487142562866},
#  {'label': 'LABEL_2', 'score': 0.9836333394050598},
#  {'label': 'LABEL_1', 'score': 0.8554912805557251},
#  {'label': 'LABEL_0', 'score': 0.9948055148124695},
#  {'label': 'LABEL_1', 'score': 0.5773965120315552},
#  {'label': 'LABEL_0', 'score': 0.9944214224815369},
#  {'label': 'LABEL_0', 'score': 0.9922870397567749},
#  {'label': 'LABEL_0', 'score': 0.9915892481803894},
#  {'label': 'LABEL_0', 'score': 0.9931180477142334},
#  {'label': 'LABEL_0', 'score': 0.9903087019920349},
#  {'label': 'LABEL_2', 'score': 0.9872887134552002},
#  {'label': 'LABEL_1', 'score': 0.9651257991790771},
#  {'label': 'LABEL_1', 'score': 0.8574497699737549},
#  {'label': 'LABEL_0', 'score': 0.9864525198936462},
#  {'label': 'LABEL_0', 'score': 0.9950782060623169},
#  {'label': 'LABEL_2', 'score': 0.5663521885871887},
#  {'label': 'LABEL_2', 'score': 0.9826592206954956},
#  {'label': 'LABEL_0', 'score': 0.9374314546585083},
#  {'label': 'LABEL_2', 'score': 0.9542965292930603},
#  {'label': 'LABEL_1', 'score': 0.9482778310775757},
#  {'label': 'LABEL_2', 'score': 0.96944260597229},
#  {'label': 'LABEL_0', 'score': 0.9879438877105713},
#  {'label': 'LABEL_0', 'score': 0.9686198234558105},
#  {'label': 'LABEL_0', 'score': 0.9811671376228333},
#  {'label': 'LABEL_0', 'score': 0.9950209856033325},
#  {'label': 'LABEL_2', 'score': 0.7443364262580872},
#  {'label': 'LABEL_0', 'score': 0.9938311576843262},
#  {'label': 'LABEL_2', 'score': 0.9624021649360657},
#  {'label': 'LABEL_1', 'score': 0.6245195865631104},
#  {'label': 'LABEL_1', 'score': 0.9050235152244568},
#  {'label': 'LABEL_0', 'score': 0.9956716299057007},
#  {'label': 'LABEL_0', 'score': 0.9950685501098633},
#  {'label': 'LABEL_2', 'score': 0.8132221698760986},
#  {'label': 'LABEL_0', 'score': 0.8034279346466064},
#  {'label': 'LABEL_2', 'score': 0.9838143587112427},
#  {'label': 'LABEL_0', 'score': 0.9958032965660095},
#  {'label': 'LABEL_0', 'score': 0.7818147540092468},
#  {'label': 'LABEL_0', 'score': 0.9900336861610413},
#  {'label': 'LABEL_0', 'score': 0.9940379858016968},
#  {'label': 'LABEL_0', 'score': 0.9963412880897522},
#  {'label': 'LABEL_2', 'score': 0.8512046933174133},
#  {'label': 'LABEL_0', 'score': 0.9932511448860168},
#  {'label': 'LABEL_1', 'score': 0.9536367058753967},
#  {'label': 'LABEL_1', 'score': 0.9417576193809509},
#  {'label': 'LABEL_0', 'score': 0.9477695822715759},
#  {'label': 'LABEL_0', 'score': 0.9919666051864624},
#  {'label': 'LABEL_0', 'score': 0.9765270948410034},
#  {'label': 'LABEL_0', 'score': 0.9957719445228577},
#  {'label': 'LABEL_2', 'score': 0.9514212608337402},
#  {'label': 'LABEL_1', 'score': 0.937673807144165},
#  {'label': 'LABEL_2', 'score': 0.9625523090362549},
#  {'label': 'LABEL_1', 'score': 0.906970739364624},
#  {'label': 'LABEL_0', 'score': 0.9764924049377441},
#  {'label': 'LABEL_0', 'score': 0.995905876159668},
#  {'label': 'LABEL_2', 'score': 0.8500837087631226},
#  {'label': 'LABEL_0', 'score': 0.95576012134552},
#  {'label': 'LABEL_0', 'score': 0.9928694367408752},
#  {'label': 'LABEL_1', 'score': 0.9696939587593079},
#  {'label': 'LABEL_0', 'score': 0.9942301511764526},
#  {'label': 'LABEL_0', 'score': 0.993212103843689},
#  {'label': 'LABEL_0', 'score': 0.9406431913375854},
#  {'label': 'LABEL_0', 'score': 0.7144203782081604},
#  {'label': 'LABEL_0', 'score': 0.9926188588142395},
#  {'label': 'LABEL_0', 'score': 0.9892640709877014},
#  {'label': 'LABEL_2', 'score': 0.924464762210846},
#  {'label': 'LABEL_1', 'score': 0.9323543906211853},
#  {'label': 'LABEL_0', 'score': 0.9942381381988525},
#  {'label': 'LABEL_0', 'score': 0.9224148988723755},
#  {'label': 'LABEL_0', 'score': 0.7805696725845337},
#  {'label': 'LABEL_2', 'score': 0.9322373270988464},
#  {'label': 'LABEL_0', 'score': 0.9713466763496399},
#  {'label': 'LABEL_0', 'score': 0.6503285765647888},
#  {'label': 'LABEL_0', 'score': 0.9475813508033752},
#  {'label': 'LABEL_0', 'score': 0.9937611222267151},
#  {'label': 'LABEL_2', 'score': 0.6623995304107666},
#  {'label': 'LABEL_1', 'score': 0.9417797327041626},
#  {'label': 'LABEL_2', 'score': 0.9841523766517639},
#  {'label': 'LABEL_0', 'score': 0.9937186241149902},
#  {'label': 'LABEL_0', 'score': 0.9957072734832764},
#  {'label': 'LABEL_2', 'score': 0.7672901153564453},
#  {'label': 'LABEL_0', 'score': 0.9955407977104187},
#  {'label': 'LABEL_0', 'score': 0.9950615763664246},
#  {'label': 'LABEL_0', 'score': 0.9944618344306946},
#  {'label': 'LABEL_1', 'score': 0.8241178393363953},
#  {'label': 'LABEL_2', 'score': 0.9605176448822021},
#  {'label': 'LABEL_2', 'score': 0.9598367810249329},
#  {'label': 'LABEL_0', 'score': 0.9840489625930786},
#  {'label': 'LABEL_2', 'score': 0.9512035250663757},
#  {'label': 'LABEL_2', 'score': 0.5939873456954956},
#  {'label': 'LABEL_0', 'score': 0.973150372505188},
#  {'label': 'LABEL_0', 'score': 0.9929676055908203},
#  {'label': 'LABEL_0', 'score': 0.996600329875946},
#  {'label': 'LABEL_0', 'score': 0.9945476055145264},
#  {'label': 'LABEL_2', 'score': 0.843055248260498},
#  {'label': 'LABEL_2', 'score': 0.9145795702934265},
#  {'label': 'LABEL_0', 'score': 0.9931979179382324},
#  {'label': 'LABEL_0', 'score': 0.9806362986564636},
#  {'label': 'LABEL_0', 'score': 0.9442430734634399},
#  {'label': 'LABEL_2', 'score': 0.7855192422866821},
#  {'label': 'LABEL_0', 'score': 0.9817954897880554},
#  {'label': 'LABEL_2', 'score': 0.9575151205062866},
#  {'label': 'LABEL_0', 'score': 0.9910067915916443},
#  {'label': 'LABEL_2', 'score': 0.4813700020313263},
#  {'label': 'LABEL_0', 'score': 0.9927420616149902},
#  {'label': 'LABEL_0', 'score': 0.96821129322052},
#  {'label': 'LABEL_0', 'score': 0.9171594381332397},
#  {'label': 'LABEL_1', 'score': 0.9320439696311951},
#  {'label': 'LABEL_0', 'score': 0.7416048049926758},
#  {'label': 'LABEL_0', 'score': 0.7766436338424683},
#  {'label': 'LABEL_1', 'score': 0.9285962581634521},
#  {'label': 'LABEL_2', 'score': 0.9713852405548096},
#  {'label': 'LABEL_0', 'score': 0.9930946826934814},
#  {'label': 'LABEL_0', 'score': 0.9942663311958313},
#  {'label': 'LABEL_1', 'score': 0.8195064067840576},
#  {'label': 'LABEL_0', 'score': 0.996733546257019},
#  {'label': 'LABEL_0', 'score': 0.9911214113235474},
#  {'label': 'LABEL_0', 'score': 0.9954648613929749},
#  {'label': 'LABEL_0', 'score': 0.9735837578773499},
#  {'label': 'LABEL_0', 'score': 0.9953551292419434},
#  {'label': 'LABEL_0', 'score': 0.9952867031097412},
#  {'label': 'LABEL_2', 'score': 0.765924334526062},
#  {'label': 'LABEL_2', 'score': 0.7185092568397522},
#  {'label': 'LABEL_2', 'score': 0.9442965388298035},
#  {'label': 'LABEL_0', 'score': 0.9927846193313599},
#  {'label': 'LABEL_2', 'score': 0.6266874670982361},
#  {'label': 'LABEL_0', 'score': 0.9958082437515259},
#  {'label': 'LABEL_0', 'score': 0.9648508429527283},
#  {'label': 'LABEL_0', 'score': 0.9908908009529114},
#  {'label': 'LABEL_0', 'score': 0.9878218770027161},
#  {'label': 'LABEL_0', 'score': 0.54228276014328},
#  {'label': 'LABEL_0', 'score': 0.9848589301109314},
#  {'label': 'LABEL_0', 'score': 0.911583662033081},
#  {'label': 'LABEL_2', 'score': 0.974907398223877},
#  {'label': 'LABEL_2', 'score': 0.9218915104866028},
#  {'label': 'LABEL_2', 'score': 0.9516851902008057},
#  {'label': 'LABEL_1', 'score': 0.9145675897598267},
#  {'label': 'LABEL_0', 'score': 0.792326807975769},
#  {'label': 'LABEL_1', 'score': 0.9622704386711121},
#  {'label': 'LABEL_1', 'score': 0.961898922920227},
#  {'label': 'LABEL_2', 'score': 0.7910827398300171},
#  {'label': 'LABEL_1', 'score': 0.8005344867706299},
#  {'label': 'LABEL_0', 'score': 0.576926052570343},
#  {'label': 'LABEL_0', 'score': 0.9915464520454407},
#  {'label': 'LABEL_0', 'score': 0.9961403012275696},
#  {'label': 'LABEL_0', 'score': 0.9937805533409119},
#  {'label': 'LABEL_1', 'score': 0.9125243425369263},
#  {'label': 'LABEL_1', 'score': 0.9682028293609619},
#  {'label': 'LABEL_0', 'score': 0.9943248629570007},
#  {'label': 'LABEL_0', 'score': 0.9680284261703491},
#  {'label': 'LABEL_0', 'score': 0.989617109298706},
#  {'label': 'LABEL_0', 'score': 0.9964488744735718},
#  {'label': 'LABEL_2', 'score': 0.8056426048278809},
#  {'label': 'LABEL_1', 'score': 0.9655314683914185},
#  {'label': 'LABEL_0', 'score': 0.642671525478363},
#  {'label': 'LABEL_0', 'score': 0.826521098613739},
#  {'label': 'LABEL_0', 'score': 0.9183250069618225},
#  {'label': 'LABEL_0', 'score': 0.9957276582717896},
#  {'label': 'LABEL_0', 'score': 0.8995804786682129},
#  {'label': 'LABEL_0', 'score': 0.6188129782676697},
#  {'label': 'LABEL_0', 'score': 0.9769878387451172},
#  {'label': 'LABEL_0', 'score': 0.9685958623886108},
#  {'label': 'LABEL_1', 'score': 0.9694300293922424},
#  {'label': 'LABEL_1', 'score': 0.8166349530220032},
#  {'label': 'LABEL_0', 'score': 0.9739102125167847},
#  {'label': 'LABEL_2', 'score': 0.6377779841423035},
#  {'label': 'LABEL_0', 'score': 0.7930248379707336},
#  {'label': 'LABEL_0', 'score': 0.9890165328979492},
#  {'label': 'LABEL_0', 'score': 0.7263187170028687},
#  {'label': 'LABEL_0', 'score': 0.588833749294281},
#  {'label': 'LABEL_0', 'score': 0.9950449466705322},
#  {'label': 'LABEL_0', 'score': 0.8842321634292603},
#  {'label': 'LABEL_0', 'score': 0.9757571816444397},
#  {'label': 'LABEL_0', 'score': 0.8174335956573486},
#  {'label': 'LABEL_0', 'score': 0.9938490986824036},
#  {'label': 'LABEL_1', 'score': 0.8080493211746216},
#  {'label': 'LABEL_0', 'score': 0.9340881705284119},
#  {'label': 'LABEL_0', 'score': 0.9779393076896667},
#  {'label': 'LABEL_0', 'score': 0.992198646068573},
#  {'label': 'LABEL_1', 'score': 0.4952182471752167},
#  {'label': 'LABEL_0', 'score': 0.9276280403137207},
#  {'label': 'LABEL_0', 'score': 0.9929298758506775},
#  {'label': 'LABEL_0', 'score': 0.4903935194015503},
#  {'label': 'LABEL_0', 'score': 0.9570924639701843},
#  {'label': 'LABEL_0', 'score': 0.9808161854743958},
#  {'label': 'LABEL_2', 'score': 0.9835969805717468},
#  {'label': 'LABEL_2', 'score': 0.9683625102043152},
#  {'label': 'LABEL_0', 'score': 0.9905451536178589},
#  {'label': 'LABEL_0', 'score': 0.8942543864250183},
#  {'label': 'LABEL_0', 'score': 0.8394866585731506},
#  {'label': 'LABEL_1', 'score': 0.9799160957336426},
#  {'label': 'LABEL_0', 'score': 0.8384431600570679},
#  {'label': 'LABEL_0', 'score': 0.5748134851455688},
#  {'label': 'LABEL_2', 'score': 0.7516441941261292},
#  {'label': 'LABEL_0', 'score': 0.9937624335289001},
#  {'label': 'LABEL_0', 'score': 0.9955840706825256},
#  {'label': 'LABEL_0', 'score': 0.9928122162818909},
#  {'label': 'LABEL_0', 'score': 0.9960306286811829},
#  {'label': 'LABEL_0', 'score': 0.6113129258155823},
#  {'label': 'LABEL_0', 'score': 0.8789405822753906},
#  {'label': 'LABEL_0', 'score': 0.9954549074172974},
#  {'label': 'LABEL_1', 'score': 0.9186976552009583},
#  {'label': 'LABEL_0', 'score': 0.9946603178977966},
#  {'label': 'LABEL_2', 'score': 0.6213523745536804},
#  {'label': 'LABEL_0', 'score': 0.9307714104652405},
#  {'label': 'LABEL_0', 'score': 0.9871588945388794},
#  {'label': 'LABEL_2', 'score': 0.9754433631896973},
#  {'label': 'LABEL_1', 'score': 0.9821102023124695},
#  {'label': 'LABEL_2', 'score': 0.9799846410751343},
#  {'label': 'LABEL_1', 'score': 0.6982688307762146},
#  {'label': 'LABEL_2', 'score': 0.6536718010902405},
#  {'label': 'LABEL_2', 'score': 0.8565201759338379},
#  {'label': 'LABEL_1', 'score': 0.8109369277954102},
#  {'label': 'LABEL_0', 'score': 0.9940270185470581},
#  {'label': 'LABEL_2', 'score': 0.9378467798233032},
#  {'label': 'LABEL_2', 'score': 0.9331243634223938},
#  {'label': 'LABEL_0', 'score': 0.9801747798919678},
#  {'label': 'LABEL_0', 'score': 0.5342557430267334},
#  {'label': 'LABEL_0', 'score': 0.9933290481567383},
#  {'label': 'LABEL_2', 'score': 0.9571003913879395},
#  {'label': 'LABEL_0', 'score': 0.9943583607673645},
#  {'label': 'LABEL_2', 'score': 0.9404866099357605},
#  {'label': 'LABEL_1', 'score': 0.8099455237388611},
#  {'label': 'LABEL_0', 'score': 0.995564877986908},
#  {'label': 'LABEL_2', 'score': 0.7754047513008118},
#  {'label': 'LABEL_0', 'score': 0.9941710829734802},
#  {'label': 'LABEL_0', 'score': 0.9962742328643799},
#  {'label': 'LABEL_2', 'score': 0.9815834164619446},
#  {'label': 'LABEL_2', 'score': 0.9498739838600159},
#  {'label': 'LABEL_0', 'score': 0.7661119103431702},
#  {'label': 'LABEL_0', 'score': 0.990613579750061},
#  {'label': 'LABEL_0', 'score': 0.9933499693870544},
#  {'label': 'LABEL_0', 'score': 0.9869645237922668},
#  {'label': 'LABEL_1', 'score': 0.9689518809318542},
#  {'label': 'LABEL_1', 'score': 0.9153289198875427},
#  {'label': 'LABEL_0', 'score': 0.9765781164169312},
#  {'label': 'LABEL_1', 'score': 0.7514128684997559},
#  {'label': 'LABEL_2', 'score': 0.9810412526130676},
#  {'label': 'LABEL_2', 'score': 0.6622034311294556},
#  {'label': 'LABEL_0', 'score': 0.9961410164833069},
#  {'label': 'LABEL_0', 'score': 0.9297611117362976},
#  {'label': 'LABEL_2', 'score': 0.9355202317237854},
#  {'label': 'LABEL_1', 'score': 0.9439582824707031},
#  {'label': 'LABEL_0', 'score': 0.9950612187385559},
#  {'label': 'LABEL_0', 'score': 0.9962376356124878},
#  {'label': 'LABEL_0', 'score': 0.9950214624404907},
#  {'label': 'LABEL_1', 'score': 0.9796255230903625},
#  {'label': 'LABEL_2', 'score': 0.9356767535209656},
#  {'label': 'LABEL_0', 'score': 0.9963788390159607},
#  {'label': 'LABEL_0', 'score': 0.9809165596961975},
#  {'label': 'LABEL_0', 'score': 0.9953439831733704},
#  {'label': 'LABEL_0', 'score': 0.9927425384521484},
#  {'label': 'LABEL_0', 'score': 0.9590923190116882},
#  {'label': 'LABEL_0', 'score': 0.9706904888153076},
#  {'label': 'LABEL_2', 'score': 0.9845414161682129},
#  {'label': 'LABEL_1', 'score': 0.9482053518295288},
#  {'label': 'LABEL_0', 'score': 0.7856847047805786},
#  {'label': 'LABEL_0', 'score': 0.925769567489624},
#  {'label': 'LABEL_0', 'score': 0.9946750402450562},
#  {'label': 'LABEL_0', 'score': 0.9803163409233093},
#  {'label': 'LABEL_2', 'score': 0.9828777313232422},
#  {'label': 'LABEL_0', 'score': 0.885330855846405},
#  {'label': 'LABEL_1', 'score': 0.9560379981994629},
#  {'label': 'LABEL_0', 'score': 0.9908455014228821},
#  {'label': 'LABEL_0', 'score': 0.5974140763282776},
#  {'label': 'LABEL_1', 'score': 0.8089113235473633},
#  {'label': 'LABEL_0', 'score': 0.9965147376060486},
#  {'label': 'LABEL_1', 'score': 0.968371570110321},
#  {'label': 'LABEL_0', 'score': 0.9962968230247498},
#  {'label': 'LABEL_0', 'score': 0.9961937665939331},
#  {'label': 'LABEL_0', 'score': 0.9955814480781555},
#  {'label': 'LABEL_0', 'score': 0.9947332143783569},
#  {'label': 'LABEL_1', 'score': 0.8394427299499512},
#  {'label': 'LABEL_1', 'score': 0.9830000400543213},
#  {'label': 'LABEL_2', 'score': 0.9732945561408997},
#  {'label': 'LABEL_0', 'score': 0.8984466791152954},
#  {'label': 'LABEL_0', 'score': 0.9886056780815125},
#  {'label': 'LABEL_0', 'score': 0.9898737668991089},
#  {'label': 'LABEL_0', 'score': 0.5771447420120239},
#  {'label': 'LABEL_0', 'score': 0.9949666857719421},
#  {'label': 'LABEL_0', 'score': 0.9957687854766846},
#  {'label': 'LABEL_0', 'score': 0.9959880709648132},
#  {'label': 'LABEL_0', 'score': 0.9870474338531494},
#  {'label': 'LABEL_0', 'score': 0.9752436280250549},
#  {'label': 'LABEL_2', 'score': 0.9859089255332947},
#  {'label': 'LABEL_2', 'score': 0.7355734705924988},
#  {'label': 'LABEL_0', 'score': 0.9747470617294312},
#  {'label': 'LABEL_1', 'score': 0.7034061551094055},
#  {'label': 'LABEL_0', 'score': 0.6711625456809998},
#  {'label': 'LABEL_0', 'score': 0.9414498209953308},
#  {'label': 'LABEL_2', 'score': 0.926063597202301},
#  {'label': 'LABEL_0', 'score': 0.994864284992218},
#  {'label': 'LABEL_0', 'score': 0.8469664454460144},
#  {'label': 'LABEL_0', 'score': 0.9226281642913818},
#  {'label': 'LABEL_1', 'score': 0.9472656846046448},
#  {'label': 'LABEL_0', 'score': 0.9856075048446655},
#  {'label': 'LABEL_0', 'score': 0.9935926795005798},
#  {'label': 'LABEL_0', 'score': 0.9892241358757019},
#  {'label': 'LABEL_0', 'score': 0.646804928779602},
#  {'label': 'LABEL_0', 'score': 0.9050678014755249},
#  {'label': 'LABEL_1', 'score': 0.970990002155304},
#  {'label': 'LABEL_0', 'score': 0.9946466088294983},
#  {'label': 'LABEL_0', 'score': 0.5832551717758179},
#  {'label': 'LABEL_0', 'score': 0.9799044132232666},
#  {'label': 'LABEL_2', 'score': 0.9837837815284729},
#  {'label': 'LABEL_0', 'score': 0.9700517654418945},
#  {'label': 'LABEL_0', 'score': 0.9950771927833557},
#  {'label': 'LABEL_2', 'score': 0.9174915552139282},
#  {'label': 'LABEL_0', 'score': 0.9837414026260376},
#  {'label': 'LABEL_0', 'score': 0.991186797618866},
#  {'label': 'LABEL_0', 'score': 0.9957242012023926},
#  {'label': 'LABEL_1', 'score': 0.9672433137893677},
#  {'label': 'LABEL_0', 'score': 0.9936355352401733},
#  {'label': 'LABEL_0', 'score': 0.684961199760437},
#  {'label': 'LABEL_0', 'score': 0.9735875129699707},
#  {'label': 'LABEL_0', 'score': 0.5751368403434753},
#  ...]

# %%
def get_label(d):
    return(int(d['label'].split('_')[1]))

test_pred = [get_label(d) for d in test_pred]

# %%
print("acc:", accuracy_score(split['test']['label'], test_pred))
# Out:
# acc: 0.8367486338797814

# %%
print("f1:", f1_score(split['test']['label'], test_pred, average='macro'))
# Out:
# f1: 0.7929431833483719

# %%
# Scikit-Learn is transitioning to V1, but ut's not available on Colab
# The changes modify how confusion matrices are plotted
def plot_cm(cm):
    classes = ['negative', 'positive', 'neutral']
    df_cm = pd.DataFrame(cm, index=classes, columns=classes)
    ax = sn.heatmap(df_cm, annot=True, fmt='.2g')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Target')

cm = confusion_matrix(split['test']['label'], test_pred, normalize='true')
plot_cm(cm)

# %% [markdown]
# END
